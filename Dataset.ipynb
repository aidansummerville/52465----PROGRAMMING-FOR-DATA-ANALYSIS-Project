# %% [markdown]
# test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats  
import seaborn as sns
import scipy.stats as stats


from matplotlib.pyplot import scatter

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("mart.csv", header=None)

# %%
df.columns = ["Lot", "Ring", "Weight", "No.Owners","Price", "Total", "Breed", "Sex","Price/Weight", "Price-Weight","Date"]

# %%
df.head()
# Out:
#    Lot Ring  Weight  No.Owners   Price   Total Breed Sex  Price/Weight  \
# 0    2   CA   590.0        1.0   980.0   980.0   AAX   M          1.66
# 1   2A   CA   570.0        1.0  1000.0  1000.0   AAX   M          1.75
# 2   2B   CA   565.0        1.0   980.0   980.0   AAX   M          1.73
# 3   2C   CA   620.0        1.0  1000.0  1000.0   AAX   M          1.61
# 4  2CC   CA   620.0        1.0  1000.0  1000.0   AAX   M          1.61
#
#    Price-Weight        Date
# 0         390.0  03/11/2018
# 1         430.0  03/11/2018
# 2         415.0  03/11/2018
# 3         380.0  03/11/2018
# 4         380.0  03/11/2018

# %%
df.shape
# Out:
# (448, 7)

# %%
df.ndim
# Out:
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-378-ddf2779c161c> in <module>()
#       3     # if more than a value,
#       4     if row == 'AAX' and 3 and 17/11/18:
# ----> 5         df.drop(row)
#       6         # else, if more than a value,
#       7     elif row == "CHX" and 3 and '17/11/18':
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.head()
# Out:
#    Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 0   590.0        1.0   980.0   AAX          1.66         390.0  03/11/2018
# 1   570.0        1.0  1000.0   AAX          1.75         430.0  03/11/2018
# 2   565.0        1.0   980.0   AAX          1.73         415.0  03/11/2018
# 3   620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 4   620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018

# %%
df.tail()
# Out:
#      Lot Ring  Weight  No.Owners  Price  Total Breed  Sex  Price/Weight  \
# 834  NaN  NaN     NaN        NaN    NaN    NaN   NaN  NaN           NaN
# 835  NaN  NaN     NaN        NaN    NaN    NaN   NaN  NaN           NaN
# 836  NaN  NaN     NaN        NaN    NaN    NaN   NaN  NaN           NaN
# 837  NaN  NaN     NaN        NaN    NaN    NaN   NaN  NaN           NaN
# 838  NaN  NaN     NaN        NaN    NaN    NaN   NaN  NaN           NaN
#
#      Price-Weight Date
# 834           NaN  NaN
# 835           NaN  NaN
# 836           NaN  NaN
# 837           NaN  NaN
# 838           NaN  NaN

# %%
df.dtypes
# Out:
# Lot              object
# Ring             object
# Weight          float64
# No.Owners       float64
# Price           float64
# Total           float64
# Breed            object
# Sex              object
# Price/Weight    float64
# Price-Weight    float64
# Date             object
# dtype: object

# %%
df.describe()
# Out:
#            Weight   No.Owners        Price        Total  Price/Weight  \
# count  591.000000  591.000000   591.000000   591.000000    591.000000
# mean   530.028765    1.262267  1081.345178  1355.067682      2.043316
# std     88.843554    0.537333   220.520784   606.227634      0.282863
# min    250.000000    1.000000   420.000000   420.000000      1.170000
# 25%    475.000000    1.000000   950.000000  1000.000000      1.850000
# 50%    530.000000    1.000000  1100.000000  1180.000000      2.110000
# 75%    582.500000    1.000000  1240.000000  1400.000000      2.260000
# max    890.000000    4.000000  1860.000000  3960.000000      2.630000
#
#        Price-Weight
# count    591.000000
# mean     551.316413
# std      165.524210
# min       85.000000
# 25%      445.000000
# 50%      575.000000
# 75%      675.000000
# max     1025.000000

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price", data=df, hue ="Breed",style ="No.Owners",size ="Price/Weight")

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price/Weight",hue ="Breed", data=df,style ="No.Owners",size ="Price/Weight")

# %%
df.groupby("Breed").describe()
# Out:
#       No.Owners                                                 Price  \
#           count      mean       std  min   25%  50%   75%  max  count
# Breed
# AAX        82.0  1.280488  0.503675  1.0  1.00  1.0  1.75  3.0   82.0
# BA          1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0    1.0
# BAX         7.0  1.285714  0.487950  1.0  1.00  1.0  1.50  2.0    7.0
# BBX        17.0  1.117647  0.332106  1.0  1.00  1.0  1.00  2.0   17.0
# CH         12.0  1.333333  0.492366  1.0  1.00  1.0  2.00  2.0   12.0
# CHX       187.0  1.213904  0.483290  1.0  1.00  1.0  1.00  3.0  187.0
# FR         14.0  1.142857  0.363137  1.0  1.00  1.0  1.00  2.0   14.0
# FRX         2.0  1.500000  0.707107  1.0  1.25  1.5  1.75  2.0    2.0
# GAX         1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0    1.0
# HEX        27.0  1.555556  0.800641  1.0  1.00  1.0  2.00  4.0   27.0
# LM         10.0  1.100000  0.316228  1.0  1.00  1.0  1.00  2.0   10.0
# ...

# %%
df = df.loc[df.Breed.isin(['AAX', 'CHX', 'LMX'])]
df
# Out:
#      Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 0     590.0        1.0   980.0   AAX          1.66         390.0  03/11/2018
# 1     570.0        1.0  1000.0   AAX          1.75         430.0  03/11/2018
# 2     565.0        1.0   980.0   AAX          1.73         415.0  03/11/2018
# 3     620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 4     620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 5     590.0        1.0   950.0   AAX          1.61         360.0  03/11/2018
# 6     560.0        1.0   970.0   AAX          1.73         410.0  03/11/2018
# 7     560.0        1.0   950.0   AAX          1.70         390.0  03/11/2018
# 8     572.0        1.0   965.0   AAX          1.69         393.0  03/11/2018
# 9     600.0        2.0  1060.0   AAX          1.77         460.0  03/11/2018
# 10    573.0        1.0   965.0   AAX          1.68         392.0  03/11/2018
# ...

# %%
df = df.drop(columns=['Lot', 'Ring','Total','Sex'])

# %%
AAXdf = df[df["Breed"] == "AAX"]
CHXdf = df[df["Breed"] == "CHX"]
LMXdf = df[df["Breed"] == "LMX"]

# %%
df.groupby("Breed").describe()
# Out:
#       No.Owners                                                Price  \
#           count      mean       std  min  25%  50%   75%  max  count
# Breed
# AAX        82.0  1.280488  0.503675  1.0  1.0  1.0  1.75  3.0   82.0
# CHX       187.0  1.213904  0.483290  1.0  1.0  1.0  1.00  3.0  187.0
# LMX       179.0  1.301676  0.607581  1.0  1.0  1.0  1.00  4.0  179.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX     962.134146  176.365975  540.0   862.5   970.0  1080.0  1360.0
# CHX    1173.181818  187.818286  620.0  1060.0  1170.0  1290.0  1860.0
# LMX    1116.396648  199.924155  520.0  1000.0  1110.0  1255.0  1640.0
#
#       Price-Weight                                                      \
#              count        mean         std    min    25%    50%    75%
# Breed
# AAX           82.0  419.280488  120.933639  128.0  347.5  410.0  490.0
# ...

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price", data=df, hue ="Breed",style ="No.Owners",size ="Price/Weight")

# %%
plt.figure(figsize=(15,15))
sns.lmplot(x="Weight", y="Price", hue="Breed", data=df)

# %%
plt.figure(figsize=(15,15))
sns.lmplot(x="Weight", y="Price/Weight", hue="Breed", data=df)

# %%
plt.figure(figsize=(15,15))
x = df["Weight"] 
ax =sns.distplot(x)

# %%
plt.figure(figsize=(15,15))
x = df["Price"] 
ax =sns.distplot(x,rug=True)

# %%
df.describe()
# Out:
#            Weight   No.Owners        Price  Price/Weight  Price-Weight
# count  448.000000  448.000000   448.000000    448.000000    448.000000
# mean   533.671875    1.261161  1111.863839      2.088393    578.191964
# std     85.028364    0.540205   204.756191      0.254344    150.634761
# min    310.000000    1.000000   520.000000      1.310000    128.000000
# 25%    480.000000    1.000000   990.000000      1.937500    480.000000
# 50%    530.000000    1.000000  1120.000000      2.145000    599.000000
# 75%    585.000000    1.000000  1250.000000      2.280000    690.000000
# max    890.000000    4.000000  1860.000000      2.630000   1025.000000

# %%
df
# Out:
#      Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 0     590.0        1.0   980.0   AAX          1.66         390.0  03/11/2018
# 1     570.0        1.0  1000.0   AAX          1.75         430.0  03/11/2018
# 2     565.0        1.0   980.0   AAX          1.73         415.0  03/11/2018
# 3     620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 4     620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 5     590.0        1.0   950.0   AAX          1.61         360.0  03/11/2018
# 6     560.0        1.0   970.0   AAX          1.73         410.0  03/11/2018
# 7     560.0        1.0   950.0   AAX          1.70         390.0  03/11/2018
# 8     572.0        1.0   965.0   AAX          1.69         393.0  03/11/2018
# 9     600.0        2.0  1060.0   AAX          1.77         460.0  03/11/2018
# 10    573.0        1.0   965.0   AAX          1.68         392.0  03/11/2018
# ...

# %%
plt.figure(figsize=(15,15))
x = CHXdf["Weight"] 
ax =sns.distplot(x,rug=True)

# %%
CHXdf.describe()
# Out:
#            Weight   No.Owners        Price  Price/Weight  Price-Weight
# count  187.000000  187.000000   187.000000    187.000000    187.000000
# mean   538.679144    1.213904  1173.181818      2.186310    634.502674
# std     89.524513    0.483290   187.818286      0.177294    117.723769
# min    350.000000    1.000000   620.000000      1.500000    230.000000
# 25%    479.000000    1.000000  1060.000000      2.085000    560.000000
# 50%    535.000000    1.000000  1170.000000      2.200000    635.000000
# 75%    592.500000    1.000000  1290.000000      2.310000    720.000000
# max    890.000000    3.000000  1860.000000      2.630000   1025.000000

# %%
mu, sigma =536.591837, 93.92371 # mean and standard deviation
>>> s = np.random.normal(mu, sigma, 49)

# %%
mu, sigma = 547.369565, 107.553885 # mean and standard deviation
>>> s2 = np.random.normal(mu, sigma, 46)

# %%
s
# Out:
# array([574.39716906, 439.3901505 , 473.44766359, 599.26321314,
#        609.3332947 , 414.31604955, 511.18631168, 432.30576098,
#        384.15842039, 372.30565178, 717.66261514, 616.04264161,
#        540.37111603, 484.84634474, 563.65861274, 551.62596615,
#        574.37770639, 551.62764977, 490.82459705, 553.76989391,
#        488.8830334 , 541.22363348, 617.25092404, 620.91196835,
#        677.68760597, 446.46045798, 622.05995226, 518.19586525,
#        507.33465467, 636.70818424, 512.94457628, 482.31655242,
#        313.84401481, 520.65914224, 521.27539205, 524.29931919,
#        648.09229372, 572.19504578, 645.9616834 , 509.85270498,
#        513.96801359, 592.50818641, 408.93263127, 502.57937441,
#        441.27130011, 370.71506204, 613.4306    , 371.82308256,
#        442.72772989])

# %%
s2
# Out:
# array([544.18074457, 648.09259356, 537.14681742, 441.26779629,
#        423.44898293, 494.21901677, 624.81749413, 614.48584788,
#        465.01614341, 476.12611251, 657.88025171, 507.96492437,
#        372.16284669, 578.52422069, 497.17126257, 750.54709156,
#        687.71241149, 655.51016123, 205.40039066, 524.90210269,
#        613.85243299, 363.97600868, 614.59699344, 586.77692463,
#        492.58335943, 692.93132597, 464.43081413, 710.32033285,
#        638.65228898, 569.84104003, 467.03831397, 540.80575751,
#        615.73397215, 498.66647099, 609.72979444, 432.89317505,
#        416.68717204, 385.14334824, 534.50081551, 607.59896153,
#        469.61620144, 539.1475215 , 617.79321907, 407.97315663,
#        496.96787918, 626.47420963])

# %%
ax =sns.distplot(s,rug=True)

# %%
ax2 =sns.distplot(s2,rug=True)

# %%
week1 = df[df["Date"] == '24/11/2018']

# %%
week1
# Out:
#      Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 476   440.0        1.0   830.0   LMX          1.89         390.0  24/11/2018
# 477   440.0        1.0   830.0   LMX          1.89         390.0  24/11/2018
# 478   435.0        1.0   700.0   AAX          1.61         265.0  24/11/2018
# 479   510.0        1.0  1120.0   CHX          2.20         610.0  24/11/2018
# 480   415.0        1.0   840.0   CHX          2.02         425.0  24/11/2018
# 481   490.0        1.0   770.0   AAX          1.57         280.0  24/11/2018
# 482   495.0        1.0   760.0   AAX          1.54         265.0  24/11/2018
# 483   450.0        1.0   830.0   AAX          1.84         380.0  24/11/2018
# 484   520.0        1.0   780.0   AAX          1.50         260.0  24/11/2018
# 485   455.0        1.0  1080.0   LMX          2.37         625.0  24/11/2018
# 486   405.0        1.0   880.0   LMX          2.17         475.0  24/11/2018
# ...

# %% [markdown]
# ### week1

# %%
week1.groupby("Breed").describe()
# Out:
#       No.Owners                                               Price  \
#           count      mean       std  min  25%  50%   75%  max count
# Breed
# AAX        14.0  1.285714  0.468807  1.0  1.0  1.0  1.75  2.0  14.0
# CHX        49.0  1.204082  0.499149  1.0  1.0  1.0  1.00  3.0  49.0
# LMX        26.0  1.153846  0.543493  1.0  1.0  1.0  1.00  3.0  26.0
#
#                                                                         \
#               mean         std    min      25%     50%     75%     max
# Breed
# AAX     884.285714  185.336048  570.0   762.50   890.0  1030.0  1160.0
# CHX    1154.591837  195.287813  620.0  1030.00  1160.0  1300.0  1530.0
# LMX    1053.461538  274.484132  650.0   851.25   995.0  1277.5  1550.0
#
#       Price-Weight                                                        \
#              count        mean         std    min     25%    50%     75%
# Breed
# AAX           14.0  365.357143  117.579176  145.0  266.25  405.0  448.75
# ...

# %%
AX= week1[week1["Breed"] == "AAX"]
CX = week1[week1["Breed"] == "CHX"]
LX = week1[week1["Breed"] == "LMX"]

# %%
AX1 = AX[AX["No.Owners"] == 1] 
AX1
AX1['Weight']
# Out:
# 478    435.0
# 481    490.0
# 482    495.0
# 483    450.0
# 484    520.0
# 507    520.0
# 516    590.0
# 523    520.0
# 566    425.0
# 574    390.0
# Name: Weight, dtype: float64

# %%
AX2 = AX[AX["No.Owners"] == 2] 
AX2
AX2['Weight']
# Out:
# 524    520.0
# 547    505.0
# 579    715.0
# 580    690.0
# Name: Weight, dtype: float64

# %%
LX1 = LX[LX["No.Owners"] == 1] 
LX1
LX1['Weight']
# Out:
# 476    440.0
# 477    440.0
# 485    455.0
# 486    405.0
# 487    480.0
# 488    475.0
# 489    450.0
# 490    400.0
# 493    400.0
# 494    410.0
# 501    375.0
# 505    515.0
# 506    520.0
# 529    490.0
# 534    660.0
# 537    670.0
# 538    690.0
# 552    705.0
# 556    360.0
# 567    645.0
# 568    710.0
# 578    575.0
# 588    410.0
# 590    430.0
# Name: Weight, dtype: float64

# %%
LX3 = LX[LX["No.Owners"] == 3] 
LX3
LX3['Weight']
# Out:
# 491    467.0
# 575    610.0
# Name: Weight, dtype: float64

# %%
CX1 = CX[CX["No.Owners"] == 1] 
CX1
CX1['Weight']
# Out:
# 479    510.0
# 480    415.0
# 502    600.0
# 503    605.0
# 510    460.0
# 511    400.0
# 512    440.0
# 513    405.0
# 514    490.0
# 515    400.0
# 518    575.0
# 525    525.0
# 526    500.0
# 527    480.0
# 528    510.0
# 530    465.0
# 531    710.0
# 532    725.0
# 535    680.0
# 536    690.0
# 541    500.0
# 542    520.0
# 543    500.0
# 544    420.0
# 548    510.0
# 549    580.0
# 551    740.0
# 553    710.0
# 554    400.0
# 555    375.0
# 570    630.0
# 576    650.0
# 577    570.0
# 581    565.0
# 582    550.0
# 583    550.0
# 584    555.0
# 585    575.0
# 586    585.0
# 587    620.0
# 589    470.0
# Name: Weight, dtype: float64

# %%
CX2 = CX[CX["No.Owners"] == 2] 
CX2
CX2['Weight']
# Out:
# 517    540.0
# 519    535.0
# 522    385.0
# 540    475.0
# 550    570.0
# 573    505.0
# Name: Weight, dtype: float64

# %%
CX3 = CX[CX["No.Owners"] == 3] 
CX3
CX3['Weight']
# Out:
# 571    580.0
# 572    543.0
# Name: Weight, dtype: float64

# %%
AX.groupby("No.Owners").describe()
# Out:
#           Price                                                             \
#           count    mean         std    min     25%     50%     75%     max
# No.Owners
# 1.0        10.0   804.0  149.086105  570.0   715.0   775.0   920.0  1050.0
# 2.0         4.0  1085.0   83.466560  970.0  1052.5  1105.0  1137.5  1160.0
#
#           Price-Weight                                                   \
#                  count   mean         std    min     25%    50%     75%
# No.Owners
# 1.0               10.0  320.5  103.587054  145.0  265.00  275.0  417.50
# 2.0                4.0  477.5   65.128079  440.0  443.75  447.5  481.25
#
#                  Price/Weight                                                 \
#              max        count    mean       std   min     25%    50%     75%
# No.Owners
# 1.0        460.0         10.0  1.6570  0.174359  1.34  1.5475  1.650  1.8175
# 2.0        575.0          4.0  1.8175  0.243088  1.62  1.6350  1.755  1.9375
#
#                 Weight
# ...

# %%
CX.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1.0        41.0  1160.487805  204.596569   620.0  1030.0  1170.0  1320.0
# 2.0         6.0  1109.166667  166.565803   835.0  1047.5  1120.0  1222.5
# 3.0         2.0  1170.000000   56.568542  1130.0  1150.0  1170.0  1190.0
#
#                   Price-Weight                                           \
#               max        count   mean         std    min     25%    50%
# No.Owners
# 1.0        1530.0         41.0  620.0  124.066514  245.0  560.00  655.0
# 2.0        1300.0          6.0  607.5  103.186724  450.0  565.00  600.0
# 3.0        1210.0          2.0  608.5   30.405592  587.0  597.75  608.5
#
#                          Price/Weight                                    \
#               75%    max        count      mean       std   min     25%
# No.Owners
# ...

# %%
LX.groupby("No.Owners").describe()
# Out:
#           Price                                                         \
#           count         mean         std    min     25%    50%     75%
# No.Owners
# 1.0        24.0  1058.333333  272.036070  650.0  853.75  995.0  1270.0
# 3.0         2.0   995.000000  417.193001  700.0  847.50  995.0  1142.5
#
#                   Price-Weight                                            \
#               max        count    mean         std    min     25%    50%
# No.Owners
# 1.0        1550.0         24.0  553.75  168.188882  275.0  423.75  530.0
# 3.0        1290.0          2.0  456.50  316.076731  233.0  344.75  456.5
#
#                          Price/Weight                                    \
#               75%    max        count      mean       std   min     25%
# No.Owners
# 1.0        675.00  840.0         24.0  2.090833  0.203062  1.73  1.9575
# 3.0        568.25  680.0          2.0  1.805000  0.431335  1.50  1.6525
#
# ...

# %% [markdown]
# ## Building A New Dataset

# %% [markdown]
# #### Week 1

# %%
14+49+28
# Out:
# 91

# %%
14/91
# Out:
# 0.15384615384615385

# %%
49/91
# Out:
# 0.5384615384615384

# %%
28/91
# Out:
# 0.3076923076923077

# %%
10/14, 4/14
# Out:
# (0.7142857142857143, 0.2857142857142857)

# %%
no = (1,2)

# %%
no2 =(1,2,3)

# %%
c1=np.corrcoef(AX1['Weight'], AX1['Price'])[0, 1]
c2 = np.corrcoef(AX2['Weight'], AX2['Price'])[0, 1]
c3=np.corrcoef(LX1['Weight'], LX1['Price'])[0, 1]
c4 = np.corrcoef(LX3['Weight'], LX3['Price'])[0, 1]
c5 = np.corrcoef(CX1['Weight'], CX1['Price'])[0, 1]
c6= np.corrcoef(CX2['Weight'], CX2['Price'])[0, 1]
c7 = np.corrcoef(CX3['Weight'], CX3['Price'])[0, 1]

# %%
41/49, 6/49, 2/49
# Out:
# (0.8367346938775511, 0.12244897959183673, 0.04081632653061224)

# %%
breed = ["AAX","CHX", "LMX"]
breed = np.random.choice(breed, 91, p=[0.154, 0.538, 0.308])

# %%
breed
# Out:
# array(['CHX', 'LMX', 'CHX', 'CHX', 'AAX', 'AAX', 'CHX', 'CHX', 'CHX',
#        'LMX', 'LMX', 'CHX', 'CHX', 'CHX', 'CHX', 'LMX', 'CHX', 'CHX',
#        'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'AAX', 'CHX', 'AAX', 'LMX',
#        'CHX', 'CHX', 'CHX', 'CHX', 'CHX', 'CHX', 'AAX', 'CHX', 'CHX',
#        'CHX', 'CHX', 'CHX', 'CHX', 'CHX', 'CHX', 'AAX', 'CHX', 'CHX',
#        'LMX', 'LMX', 'CHX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX',
#        'CHX', 'CHX', 'LMX', 'CHX', 'AAX', 'CHX', 'CHX', 'LMX', 'LMX',
#        'CHX', 'CHX', 'CHX', 'LMX', 'CHX', 'CHX', 'CHX', 'CHX', 'CHX',
#        'CHX', 'CHX', 'AAX', 'AAX', 'LMX', 'LMX', 'AAX', 'CHX', 'CHX',
#        'CHX', 'CHX', 'AAX', 'AAX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX',
#        'CHX'], dtype='<U3')

# %%
ndf = pd.DataFrame(breed, columns = ['Breed'])

No_Owners = []


# For each row in the column,
for row in ndf['Breed']:
    # if more than a value,
    if row == "AAX":
        a = np.random.choice(no, p=[0.714, 0.286])
        No_Owners.append(a)
    # else, if more than a value,
    elif row == "LMX":
        b = np.random.choice(no2,p=[41/49, 6/49, 2/49])
        # Append a letter grade
        No_Owners.append(b)
    # else, if more than a value,
    elif row == "CHX":
        c = np.random.choice(no,p=[24/26, 2/26])
        # Append a letter grade
        No_Owners.append(c)

# Create a column from the list
ndf['No.Owners'] = No_Owners

ndf
# Out:
#    Breed  No.Owners
# 0    CHX          1
# 1    LMX          1
# 2    CHX          1
# 3    CHX          1
# 4    AAX          1
# 5    AAX          2
# 6    CHX          1
# 7    CHX          1
# 8    CHX          1
# 9    LMX          1
# 10   LMX          1
# 11   CHX          1
# 12   CHX          1
# 13   CHX          1
# 14   CHX          2
# 15   LMX          1
# 16   CHX          2
# 17   CHX          1
# 18   LMX          1
# 19   CHX          1
# 20   LMX          1
# 21   CHX          1
# 22   LMX          1
# 23   AAX          1
# 24   CHX          1
# 25   AAX          1
# 26   LMX          1
# 27   CHX          1
# 28   CHX          1
# 29   CHX          2
# 30   CHX          1
# 31   CHX          1
# 32   CHX          1
# 33   AAX          1
# 34   CHX          1
# 35   CHX          1
# 36   CHX          1
# 37   CHX          1
# 38   CHX          1
# 39   CHX          1
# 40   CHX          1
# 41   CHX          1
# 42   AAX          1
# 43   CHX          1
# ...

# %%
price = []

# For each row in the column,
for row in ndf['Breed']:
    # if more than a value,
    if row == "AAX" and 1:
        xx = np.array([390.0, 590.0])
        yy = np.array([570.0, 1050.0])
        means = [483.5,804.0]  
        stds = [58.833569, 149.086105 ]
        corr = c1 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        d = np.random.multivariate_normal(means, covs)
        price.append(d)
    # else, if more than a value,
    elif row == "AAX" and 2:
        xx = np.array([505, 715])
        yy = np.array([970.0, 1160.0])
        means = [607.5,1085.0]  
        stds = [110.340382, 83.466560 ]
        corr = c2 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        e = np.random.multivariate_normal(means, covs)
        price.append(e)
    elif row == "LMX" and 1:
        xx = np.array([360, 710])
        yy = np.array([650.0, 1550.0])
        means = [504.583333,1058.333333]  
        stds = [114.53039, 272.036070 ]
        corr = c3 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 3:
        xx = np.array([467.0, 610.0])
        yy = np.array([700.0, 1290.0])
        means = [538.500000,995.000000]  
        stds = [101.11627, 417.193001 ]
        corr = c4 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        g = np.random.multivariate_normal(means, covs)
        price.append(g) 
    elif row == "CHX" and 1:
        xx = np.array([375.0, 740.0])
        yy = np.array([620.0, 1530.0])
        means = [540.487805,1160.487805]  
        stds = [98.993717, 204.596569 ]
        corr = c5 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        h = np.random.multivariate_normal(means, covs)
        price.append(h)
    elif row == "CHX" and 2:
        xx = np.array([385.0, 570.0])
        yy = np.array([835.0, 1300.0])
        means = [501.666667,1109.166667]  
        stds = [65.701344, 166.565803 ]
        corr = c6 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        i = np.random.multivariate_normal(means, covs)
        price.append(i)
    elif row == "CHX" and 3:
        xx = np.array([543.0, 580.0])
        yy = np.array([1130.0, 1210.0])
        means = [561.500000,1170.000000]  
        stds = [26.162951, 56.568542 ]
        corr = c7 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        j = np.random.multivariate_normal(means, covs)
        price.append(j)

# Create a column from the list

ndf
# Out:
#    Breed  No.Owners
# 0    CHX          1
# 1    LMX          1
# 2    CHX          1
# 3    CHX          1
# 4    AAX          1
# 5    AAX          2
# 6    CHX          1
# 7    CHX          1
# 8    CHX          1
# 9    LMX          1
# 10   LMX          1
# 11   CHX          1
# 12   CHX          1
# 13   CHX          1
# 14   CHX          2
# 15   LMX          1
# 16   CHX          2
# 17   CHX          1
# 18   LMX          1
# 19   CHX          1
# 20   LMX          1
# 21   CHX          1
# 22   LMX          1
# 23   AAX          1
# 24   CHX          1
# 25   AAX          1
# 26   LMX          1
# 27   CHX          1
# 28   CHX          1
# 29   CHX          2
# 30   CHX          1
# 31   CHX          1
# 32   CHX          1
# 33   AAX          1
# 34   CHX          1
# 35   CHX          1
# 36   CHX          1
# 37   CHX          1
# 38   CHX          1
# 39   CHX          1
# 40   CHX          1
# 41   CHX          1
# 42   AAX          1
# 43   CHX          1
# ...

# %%
price =   np.concatenate([price], axis=1)
price
# Out:
# array([[ 513.47085013, 1095.68532117],
#        [ 645.91891046, 1275.67259994],
#        [ 740.31425527, 1567.48285571],
#        [ 499.67427318, 1112.36423129],
#        [ 446.12357115,  778.08687699],
#        [ 583.66514456,  942.79814914],
#        [ 400.07004063,  873.00483478],
#        [ 637.93797379, 1076.85591922],
#        [ 649.87041598, 1518.36684617],
#        [ 685.61585779, 1657.08922324],
#        [ 637.70941979, 1344.94564497],
#        [ 640.15575701, 1311.08181334],
#        [ 519.67421752, 1305.15840734],
#        [ 764.13342488, 1577.21097083],
#        [ 775.34771598, 1560.5320635 ],
#        [ 443.71728905,  905.7056493 ],
#        [ 494.15215576,  746.4525327 ],
#        [ 389.41919419,  836.26723169],
#        [ 601.50212097, 1265.31020712],
#        [ 712.80578345, 1487.98800507],
#        [ 591.75218035, 1081.72826456],
#        [ 571.33421025, 1139.96424994],
#        [ 420.88565723,  763.77860902],
#        [ 490.59378728,  804.03420766],
# ...

# %%
nprice = price[:,1]

# %%
weight = price[:,0]

# %%
ndf['Weight'] = weight
ndf['Price']  = nprice
ndf
# Out:
#    Breed  No.Owners      Weight        Price
# 0    CHX          1  513.470850  1095.685321
# 1    LMX          1  645.918910  1275.672600
# 2    CHX          1  740.314255  1567.482856
# 3    CHX          1  499.674273  1112.364231
# 4    AAX          1  446.123571   778.086877
# 5    AAX          2  583.665145   942.798149
# 6    CHX          1  400.070041   873.004835
# 7    CHX          1  637.937974  1076.855919
# 8    CHX          1  649.870416  1518.366846
# 9    LMX          1  685.615858  1657.089223
# 10   LMX          1  637.709420  1344.945645
# 11   CHX          1  640.155757  1311.081813
# 12   CHX          1  519.674218  1305.158407
# 13   CHX          1  764.133425  1577.210971
# 14   CHX          2  775.347716  1560.532063
# 15   LMX          1  443.717289   905.705649
# 16   CHX          2  494.152156   746.452533
# 17   CHX          1  389.419194   836.267232
# 18   LMX          1  601.502121  1265.310207
# 19   CHX          1  712.805783  1487.988005
# ...

# %%
ndf['Price/Weight'] = ndf['Price']/ndf['Weight']
ndf
# Out:
#    Breed  No.Owners      Weight        Price  Price/Weight
# 0    CHX          1  513.470850  1095.685321      2.133880
# 1    LMX          1  645.918910  1275.672600      1.974973
# 2    CHX          1  740.314255  1567.482856      2.117321
# 3    CHX          1  499.674273  1112.364231      2.226179
# 4    AAX          1  446.123571   778.086877      1.744106
# 5    AAX          2  583.665145   942.798149      1.615307
# 6    CHX          1  400.070041   873.004835      2.182130
# 7    CHX          1  637.937974  1076.855919      1.688026
# 8    CHX          1  649.870416  1518.366846      2.336415
# 9    LMX          1  685.615858  1657.089223      2.416935
# 10   LMX          1  637.709420  1344.945645      2.109026
# 11   CHX          1  640.155757  1311.081813      2.048067
# 12   CHX          1  519.674218  1305.158407      2.511493
# 13   CHX          1  764.133425  1577.210971      2.064052
# 14   CHX          2  775.347716  1560.532063      2.012687
# ...

# %%
ndf['Price-Weight'] = ndf['Price']- ndf['Weight']

# %%
ndf
# Out:
#    Breed  No.Owners      Weight        Price  Price/Weight  Price-Weight
# 0    CHX          1  513.470850  1095.685321      2.133880    582.214471
# 1    LMX          1  645.918910  1275.672600      1.974973    629.753689
# 2    CHX          1  740.314255  1567.482856      2.117321    827.168600
# 3    CHX          1  499.674273  1112.364231      2.226179    612.689958
# 4    AAX          1  446.123571   778.086877      1.744106    331.963306
# 5    AAX          2  583.665145   942.798149      1.615307    359.133005
# 6    CHX          1  400.070041   873.004835      2.182130    472.934794
# 7    CHX          1  637.937974  1076.855919      1.688026    438.917945
# 8    CHX          1  649.870416  1518.366846      2.336415    868.496430
# 9    LMX          1  685.615858  1657.089223      2.416935    971.473365
# 10   LMX          1  637.709420  1344.945645      2.109026    707.236225
# 11   CHX          1  640.155757  1311.081813      2.048067    670.926056
# ...

# %%
ndf.groupby('Breed').describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        12.0  1.166667  0.389249  1.0  1.0  1.0  1.0  2.0  12.0
# CHX        58.0  1.068966  0.255609  1.0  1.0  1.0  1.0  2.0  58.0
# LMX        21.0  1.238095  0.624881  1.0  1.0  1.0  1.0  3.0  21.0
#
#                                                                       \
#               mean         std         min          25%          50%
# Breed
# AAX     758.471518  126.874782  516.835368   722.837990   786.157288
# CHX    1169.105317  235.130042  637.242932  1050.168049  1172.958044
# LMX    1083.821530  318.991409  561.757532   805.661746  1081.728265
#
#                                 Price-Weight                          \
#                75%          max        count        mean         std
# Breed
# AAX     810.095906   942.798149         12.0  287.538431   91.323046
# ...

# %%
ndf['Date'] = '24/11/2018'
ndf
# Out:
#    Breed  No.Owners      Weight        Price  Price/Weight  Price-Weight  \
# 0    CHX          1  513.470850  1095.685321      2.133880    582.214471
# 1    LMX          1  645.918910  1275.672600      1.974973    629.753689
# 2    CHX          1  740.314255  1567.482856      2.117321    827.168600
# 3    CHX          1  499.674273  1112.364231      2.226179    612.689958
# 4    AAX          1  446.123571   778.086877      1.744106    331.963306
# 5    AAX          2  583.665145   942.798149      1.615307    359.133005
# 6    CHX          1  400.070041   873.004835      2.182130    472.934794
# 7    CHX          1  637.937974  1076.855919      1.688026    438.917945
# 8    CHX          1  649.870416  1518.366846      2.336415    868.496430
# 9    LMX          1  685.615858  1657.089223      2.416935    971.473365
# 10   LMX          1  637.709420  1344.945645      2.109026    707.236225
# 11   CHX          1  640.155757  1311.081813      2.048067    670.926056
# ...

# %% [markdown]
# #### Week2

# %%
week2 = df[df["Date"] == '17/11/2018']

# %%
week2
# Out:
#      Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 330   425.0        1.0  1010.0   CHX          2.38         585.0  17/11/2018
# 331   440.0        1.0  1040.0   LMX          2.36         600.0  17/11/2018
# 332   485.0        1.0  1080.0   LMX          2.23         595.0  17/11/2018
# 333   505.0        1.0   950.0   LMX          1.88         445.0  17/11/2018
# 336   435.0        1.0   955.0   CHX          2.20         520.0  17/11/2018
# 337   490.0        1.0   800.0   LMX          1.63         310.0  17/11/2018
# 338   385.0        1.0   600.0   AAX          1.56         215.0  17/11/2018
# 339   580.0        1.0   800.0   LMX          1.38         220.0  17/11/2018
# 341   560.0        1.0  1060.0   LMX          1.89         500.0  17/11/2018
# 344   765.0        1.0  1140.0   AAX          1.49         375.0  17/11/2018
# 348   560.0        1.0  1270.0   LMX          2.27         710.0  17/11/2018
# ...

# %%
week2.groupby("Breed").describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        17.0  1.352941  0.606339  1.0  1.0  1.0  2.0  3.0  17.0
# CHX        46.0  1.260870  0.491473  1.0  1.0  1.0  1.0  3.0  46.0
# LMX        50.0  1.260000  0.564602  1.0  1.0  1.0  1.0  3.0  50.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX    1007.647059  173.260260  600.0   900.0  1010.0  1100.0  1360.0
# CHX    1167.934783  200.079362  910.0  1032.5  1120.0  1267.5  1860.0
# LMX    1093.000000  156.286628  720.0  1025.0  1085.0  1205.0  1500.0
#
#       Price-Weight                                                        \
#              count        mean         std    min     25%    50%     75%
# Breed
# AAX           17.0  441.941176  121.169030  215.0  375.00  390.0  525.00
# ...

# %%
AXW= week2[week2["Breed"] == "AAX"]
CXW = week2[week2["Breed"] == "CHX"]
LXW = week2[week2["Breed"] == "LMX"]

# %%
AXW1 = AXW[AXW["No.Owners"] == 1] 
AXW1
AXW1['Weight']
# Out:
# 338    385.0
# 344    765.0
# 365    495.0
# 411    635.0
# 415    595.0
# 425    690.0
# 448    585.0
# 449    640.0
# 450    620.0
# 465    590.0
# 466    485.0
# 467    510.0
# Name: Weight, dtype: float64

# %%
AXW2 = AXW[AXW["No.Owners"] == 2] 
AXW2
AXW2['Weight']
# Out:
# 363    510.0
# 364    550.0
# 374    560.0
# 446    488.0
# Name: Weight, dtype: float64

# %%
AXW3 = AXW[AXW["No.Owners"] == 3] 
AXW3
AXW3['Weight']
# Out:
# 375    514.0
# Name: Weight, dtype: float64

# %%
LXW1 = LXW[LXW["No.Owners"] == 1] 
LXW1
LXW1['Weight']
# Out:
# 331    440.0
# 332    485.0
# 333    505.0
# 337    490.0
# 339    580.0
# 341    560.0
# 348    560.0
# 349    515.0
# 355    620.0
# 356    495.0
# 366    550.0
# 382    470.0
# 383    480.0
# 385    560.0
# 387    525.0
# 389    515.0
# 395    530.0
# 397    470.0
# 403    550.0
# 404    580.0
# 405    535.0
# 407    525.0
# 410    565.0
# 412    555.0
# 413    550.0
# 424    655.0
# 430    395.0
# 438    535.0
# 439    540.0
# 443    425.0
# 447    440.0
# 452    445.0
# 453    430.0
# 457    545.0
# 458    590.0
# 459    560.0
# 463    500.0
# 469    510.0
# 470    485.0
# 473    580.0
# Name: Weight, dtype: float64

# %%
LXW2 = LXW[LXW["No.Owners"] == 2] 
LXW2
LXW2['Weight']
# Out:
# 350    515.0
# 351    538.0
# 354    528.0
# 357    495.0
# 401    450.0
# 423    745.0
# 475    480.0
# Name: Weight, dtype: float64

# %%
LXW3 = LXW[LXW["No.Owners"] == 3] 
LXW3
LXW3['Weight']
# Out:
# 460    514.0
# 461    500.0
# 462    514.0
# Name: Weight, dtype: float64

# %%
CXW1 = CXW[CXW["No.Owners"] == 1] 
CXW1
CXW1['Weight']
# Out:
# 330    425.0
# 336    435.0
# 358    465.0
# 359    550.0
# 361    860.0
# 362    890.0
# 376    425.0
# 377    630.0
# 378    620.0
# 379    580.0
# 380    530.0
# 381    530.0
# 386    650.0
# 390    585.0
# 406    560.0
# 408    590.0
# 418    590.0
# 419    555.0
# 420    610.0
# 421    595.0
# 434    610.0
# 435    610.0
# 436    635.0
# 437    535.0
# 440    590.0
# 441    430.0
# 442    545.0
# 445    645.0
# 451    480.0
# 455    425.0
# 456    410.0
# 464    550.0
# 468    490.0
# 471    460.0
# 474    525.0
# Name: Weight, dtype: float64

# %%
CXW2 = CXW[CXW["No.Owners"] == 2] 
CXW2
CXW2['Weight']
# Out:
# 394    555.0
# 399    452.0
# 409    578.0
# 426    490.0
# 427    490.0
# 428    440.0
# 429    450.0
# 432    400.0
# 433    762.0
# 472    555.0
# Name: Weight, dtype: float64

# %%
CXW3 = CXW[CXW["No.Owners"] == 3] 
CXW3
CXW3['Weight']
# Out:
# 431    392.0
# Name: Weight, dtype: float64

# %%
AXW.groupby("No.Owners").describe()
# Out:
#           Price                                                         \
#           count         mean         std    min    25%     50%     75%
# No.Owners
# 1.0        12.0  1040.833333  194.537135  600.0  955.0  1060.0  1132.5
# 2.0         4.0   935.000000   77.674535  850.0  887.5   930.0   977.5
# 3.0         1.0   900.000000         NaN  900.0  900.0   900.0   900.0
#
#                   Price-Weight                                               \
#               max        count        mean         std    min    25%    50%
# No.Owners
# 1.0        1360.0         12.0  457.916667  140.719875  215.0  370.0  445.0
# 2.0        1030.0          4.0  408.000000   45.782093  362.0  383.0  400.0
# 3.0         900.0          1.0  386.000000         NaN  386.0  386.0  386.0
#
#                          Price/Weight                                    \
#               75%    max        count      mean       std   min     25%
# No.Owners
# ...

# %%
LXW.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1.0        40.0  1089.500000  144.078860   720.0  1035.0  1085.0  1195.0
# 2.0         7.0  1207.142857  152.502927  1050.0  1115.0  1160.0  1255.0
# 3.0         3.0   873.333333   75.055535   830.0   830.0   830.0   895.0
#
#                   Price-Weight                                                \
#               max        count        mean         std    min     25%    50%
# No.Owners
# 1.0        1350.0         40.0  568.375000  119.488158  220.0  528.75  595.0
# 2.0        1500.0          7.0  671.285714   66.547513  570.0  632.50  665.0
# 3.0         960.0          3.0  364.000000   83.138439  316.0  316.00  316.0
#
#                          Price/Weight                                    \
#               75%    max        count      mean       std   min     25%
# No.Owners
# ...

# %%
CXW.groupby("No.Owners").describe()
# Out:
#           Price                                                          \
#           count         mean         std    min     25%     50%     75%
# No.Owners
# 1.0        35.0  1191.857143  209.825157  920.0  1050.0  1160.0  1270.0
# 2.0        10.0  1109.000000  144.641319  910.0  1017.5  1075.0  1230.0
# 3.0         1.0   920.000000         NaN  920.0   920.0   920.0   920.0
#
#                   Price-Weight                                               \
#               max        count        mean         std    min    25%    50%
# No.Owners
# 1.0        1860.0         35.0  631.428571  120.870442  490.0  545.0  600.0
# 2.0        1330.0         10.0  591.800000   91.438868  480.0  533.5  580.0
# 3.0         920.0          1.0  528.000000         NaN  528.0  528.0  528.0
#
#                          Price/Weight                                          \
#              75%     max        count      mean       std   min    25%    50%
# No.Owners
# ...

# %%
d1=np.corrcoef(AXW1['Weight'], AXW1['Price'])[0, 1]
d2 = np.corrcoef(AXW2['Weight'], AXW2['Price'])[0, 1]
##d3 = np.corrcoef(AXW3['Weight'], AXW3['Price'])[0, 1]
d4 = np.corrcoef(LXW1['Weight'], LXW1['Price'])[0, 1]
d5 = np.corrcoef(LXW2['Weight'], LXW2['Price'])[0, 1]
d6 = np.corrcoef(LXW3['Weight'], LXW3['Price'])[0, 1]
d7 = np.corrcoef(CXW1['Weight'], CXW1['Price'])[0, 1]
d8= np.corrcoef(CXW2['Weight'], CXW2['Price'])[0, 1]
##d9 = np.corrcoef(CXW3['Weight'], CXW3['Price'])[0, 1]

# %%
breed2 = ["AAX","CHX", "LMX"]
breed2 = np.random.choice(breed2, 111, p=[16/111,45/111 , 50/111])

# %%
breed2
# Out:
# array(['LMX', 'CHX', 'AAX', 'LMX', 'LMX', 'CHX', 'AAX', 'LMX', 'LMX',
#        'LMX', 'LMX', 'LMX', 'LMX', 'CHX', 'LMX', 'CHX', 'AAX', 'LMX',
#        'LMX', 'CHX', 'LMX', 'CHX', 'CHX', 'CHX', 'CHX', 'CHX', 'CHX',
#        'CHX', 'LMX', 'LMX', 'LMX', 'CHX', 'LMX', 'AAX', 'CHX', 'LMX',
#        'LMX', 'LMX', 'LMX', 'CHX', 'CHX', 'CHX', 'CHX', 'LMX', 'LMX',
#        'CHX', 'LMX', 'CHX', 'LMX', 'LMX', 'CHX', 'CHX', 'AAX', 'CHX',
#        'CHX', 'CHX', 'CHX', 'AAX', 'CHX', 'AAX', 'LMX', 'CHX', 'AAX',
#        'LMX', 'LMX', 'CHX', 'AAX', 'LMX', 'CHX', 'LMX', 'LMX', 'LMX',
#        'LMX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX',
#        'CHX', 'LMX', 'CHX', 'CHX', 'LMX', 'CHX', 'LMX', 'LMX', 'CHX',
#        'LMX', 'LMX', 'LMX', 'LMX', 'CHX', 'AAX', 'LMX', 'LMX', 'AAX',
#        'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'CHX', 'LMX', 'AAX',
#        'CHX', 'LMX', 'CHX'], dtype='<U3')

# %%
ndf2 = pd.DataFrame(breed2, columns = ['Breed'])

No_Owners2 = []


# For each row in the column,
for row in ndf2['Breed']:
    # if more than a value,
    if row == "AAX":
        a = np.random.choice(no, p=[12/16, 4/16])
        No_Owners2.append(a)
    # else, if more than a value,
    elif row == "LMX":
        b = np.random.choice(no2,p=[40/50, 7/50, 3/50])
        # Append a letter grade
        No_Owners2.append(b)
    # else, if more than a value,
    elif row == "CHX":
        c = np.random.choice(no,p=[35/45, 10/45])
        # Append a letter grade
        No_Owners2.append(c)

# Create a column from the list
ndf2['No.Owners'] = No_Owners2

ndf2
# Out:
#     Breed  No.Owners
# 0     LMX          1
# 1     CHX          1
# 2     AAX          2
# 3     LMX          3
# 4     LMX          1
# 5     CHX          1
# 6     AAX          1
# 7     LMX          1
# 8     LMX          1
# 9     LMX          1
# 10    LMX          1
# 11    LMX          1
# 12    LMX          1
# 13    CHX          1
# 14    LMX          1
# 15    CHX          1
# 16    AAX          1
# 17    LMX          1
# 18    LMX          1
# 19    CHX          2
# 20    LMX          1
# 21    CHX          1
# 22    CHX          2
# 23    CHX          2
# 24    CHX          1
# 25    CHX          2
# 26    CHX          2
# 27    CHX          1
# 28    LMX          2
# 29    LMX          1
# 30    LMX          1
# 31    CHX          1
# 32    LMX          1
# 33    AAX          1
# 34    CHX          1
# 35    LMX          1
# 36    LMX          1
# 37    LMX          1
# 38    LMX          3
# 39    CHX          2
# 40    CHX          1
# 41    CHX          1
# ...

# %%
price2 = []

# For each row in the column,
for row in ndf2['Breed']:
    # if more than a value,
    if row == "AAX" and 1:
        xx = np.array([385.0, 765.0])
        yy = np.array([600.0, 1360.0])
        means = [582.916667,1040.833333]  
        stds = [101.789853, 194.537135 ]
        corr = d1 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        d = np.random.multivariate_normal(means, covs)
        price2.append(d)
    # else, if more than a value,
    elif row == "AAX" and 2:
        xx = np.array([488.0, 560.0])
        yy = np.array([850.0, 1030.0])
        means = [527.000000,935.000000]  
        stds = [33.803353, 77.674535 ]
        corr = d2 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        e = np.random.multivariate_normal(means, covs)
        price2.append(e)
    elif row == "LMX" and 1:
        xx = np.array([395.0, 655.0])
        yy = np.array([720.0, 1350.0])
        means = [521.125000,1089.500000]  
        stds = [55.556480, 144.078860 ]
        corr = d4 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price2.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 2:
        xx = np.array([450.0, 745.0])
        yy = np.array([1050.0, 1500.0])
        means = [535.857143,1207.142857]  
        stds = [96.956053, 152.502927]
        corr = d5 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price2.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 3:
        xx = np.array([500.0, 514.0])
        yy = np.array([830.0, 960.0])
        means = [509.333333,873.333333]  
        stds = [8.082904, 75.055535 ]
        corr = d6 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        g = np.random.multivariate_normal(means, covs)
        price2.append(g) 
    elif row == "CHX" and 1:
        xx = np.array([410.0, 890.0])
        yy = np.array([920.0, 1860.0])
        means = [560.428571,1191.857143]  
        stds = [106.40082, 209.825157]
        corr = d7 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        h = np.random.multivariate_normal(means, covs)
        price2.append(h)
    elif row == "CHX" and 2:
        xx = np.array([400.0, 762.0])
        yy = np.array([910.0, 1330.0])
        means = [517.200000,1109.000000]  
        stds = [103.507166, 144.641319 ]
        corr = d8 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        i = np.random.multivariate_normal(means, covs)
        price2.append(i)


# Create a column from the list

ndf2
# Out:
#     Breed  No.Owners
# 0     LMX          1
# 1     CHX          1
# 2     AAX          2
# 3     LMX          3
# 4     LMX          1
# 5     CHX          1
# 6     AAX          1
# 7     LMX          1
# 8     LMX          1
# 9     LMX          1
# 10    LMX          1
# 11    LMX          1
# 12    LMX          1
# 13    CHX          1
# 14    LMX          1
# 15    CHX          1
# 16    AAX          1
# 17    LMX          1
# 18    LMX          1
# 19    CHX          2
# 20    LMX          1
# 21    CHX          1
# 22    CHX          2
# 23    CHX          2
# 24    CHX          1
# 25    CHX          2
# 26    CHX          2
# 27    CHX          1
# 28    LMX          2
# 29    LMX          1
# 30    LMX          1
# 31    CHX          1
# 32    LMX          1
# 33    AAX          1
# 34    CHX          1
# 35    LMX          1
# 36    LMX          1
# 37    LMX          1
# 38    LMX          3
# 39    CHX          2
# 40    CHX          1
# 41    CHX          1
# ...

# %%
price2 =   np.concatenate([price2], axis=1)
price2
# Out:
# array([[ 588.72017544, 1116.44627875],
#        [ 592.47689131, 1335.04555527],
#        [ 602.08396603, 1145.30538265],
#        [ 571.67895861, 1214.82308007],
#        [ 521.21413722, 1164.80914975],
#        [ 564.06321307, 1289.55786006],
#        [ 517.69329069,  905.92311259],
#        [ 584.95313313, 1353.64438539],
#        [ 487.52083388,  960.42019532],
#        [ 498.24848523,  944.70181212],
#        [ 519.01979219, 1040.46213136],
#        [ 527.41644074, 1138.26575772],
#        [ 566.16223757,  889.11840091],
#        [ 419.85781907,  948.88258235],
#        [ 547.8816559 , 1246.03797463],
#        [ 759.17758379, 1458.06844033],
#        [ 557.7878337 , 1148.14026046],
#        [ 499.98157895,  968.5137102 ],
#        [ 471.83695599, 1055.96131215],
#        [ 683.22379134, 1499.23684085],
#        [ 514.39091643, 1081.41831058],
#        [ 392.85394582,  985.1867754 ],
#        [ 498.37197619, 1073.46771919],
#        [ 695.30590617, 1301.96799408],
# ...

# %%
nprice2 = price2[:,1]

# %%
weight2 = price2[:,0]

# %%
ndf2['Weight'] = weight2
ndf2['Price']  = nprice2
ndf2
# Out:
#     Breed  No.Owners      Weight        Price
# 0     LMX          1  588.720175  1116.446279
# 1     CHX          1  592.476891  1335.045555
# 2     AAX          2  602.083966  1145.305383
# 3     LMX          3  571.678959  1214.823080
# 4     LMX          1  521.214137  1164.809150
# 5     CHX          1  564.063213  1289.557860
# 6     AAX          1  517.693291   905.923113
# 7     LMX          1  584.953133  1353.644385
# 8     LMX          1  487.520834   960.420195
# 9     LMX          1  498.248485   944.701812
# 10    LMX          1  519.019792  1040.462131
# 11    LMX          1  527.416441  1138.265758
# 12    LMX          1  566.162238   889.118401
# 13    CHX          1  419.857819   948.882582
# 14    LMX          1  547.881656  1246.037975
# 15    CHX          1  759.177584  1458.068440
# 16    AAX          1  557.787834  1148.140260
# 17    LMX          1  499.981579   968.513710
# 18    LMX          1  471.836956  1055.961312
# ...

# %%
ndf2['Price/Weight'] = ndf2['Price']/ndf2['Weight']
ndf2
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight
# 0     LMX          1  588.720175  1116.446279      1.896395
# 1     CHX          1  592.476891  1335.045555      2.253329
# 2     AAX          2  602.083966  1145.305383      1.902235
# 3     LMX          3  571.678959  1214.823080      2.125009
# 4     LMX          1  521.214137  1164.809150      2.234800
# 5     CHX          1  564.063213  1289.557860      2.286194
# 6     AAX          1  517.693291   905.923113      1.749922
# 7     LMX          1  584.953133  1353.644385      2.314107
# 8     LMX          1  487.520834   960.420195      1.970009
# 9     LMX          1  498.248485   944.701812      1.896046
# 10    LMX          1  519.019792  1040.462131      2.004668
# 11    LMX          1  527.416441  1138.265758      2.158192
# 12    LMX          1  566.162238   889.118401      1.570430
# 13    CHX          1  419.857819   948.882582      2.260009
# 14    LMX          1  547.881656  1246.037975      2.274283
# ...

# %%
ndf2['Price-Weight'] = ndf2['Price']- ndf2['Weight']

# %%
ndf2['Date'] = '17/11/2018'
ndf2
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight  Price-Weight  \
# 0     LMX          1  588.720175  1116.446279      1.896395    527.726103
# 1     CHX          1  592.476891  1335.045555      2.253329    742.568664
# 2     AAX          2  602.083966  1145.305383      1.902235    543.221417
# 3     LMX          3  571.678959  1214.823080      2.125009    643.144121
# 4     LMX          1  521.214137  1164.809150      2.234800    643.595013
# 5     CHX          1  564.063213  1289.557860      2.286194    725.494647
# 6     AAX          1  517.693291   905.923113      1.749922    388.229822
# 7     LMX          1  584.953133  1353.644385      2.314107    768.691252
# 8     LMX          1  487.520834   960.420195      1.970009    472.899361
# 9     LMX          1  498.248485   944.701812      1.896046    446.453327
# 10    LMX          1  519.019792  1040.462131      2.004668    521.442339
# 11    LMX          1  527.416441  1138.265758      2.158192    610.849317
# ...

# %%
ndf2.groupby('Breed').describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        12.0  1.083333  0.288675  1.0  1.0  1.0  1.0  2.0  12.0
# CHX        46.0  1.217391  0.417029  1.0  1.0  1.0  1.0  2.0  46.0
# LMX        53.0  1.245283  0.585257  1.0  1.0  1.0  1.0  3.0  53.0
#
#                                                                       \
#               mean         std         min          25%          50%
# Breed
# AAX    1143.511662  183.335294  747.274692  1105.676296  1148.559568
# CHX    1198.570109  204.689459  699.055270  1069.132654  1194.887079
# LMX    1085.750868  147.583009  793.439996   973.318614  1082.085478
#
#                                 Price-Weight                          \
#                75%          max        count        mean         std
# Breed
# AAX    1224.213926  1426.994338         12.0  575.047320  131.676276
# ...

# %%
week2.groupby('Breed').describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        17.0  1.352941  0.606339  1.0  1.0  1.0  2.0  3.0  17.0
# CHX        46.0  1.260870  0.491473  1.0  1.0  1.0  1.0  3.0  46.0
# LMX        50.0  1.260000  0.564602  1.0  1.0  1.0  1.0  3.0  50.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX    1007.647059  173.260260  600.0   900.0  1010.0  1100.0  1360.0
# CHX    1167.934783  200.079362  910.0  1032.5  1120.0  1267.5  1860.0
# LMX    1093.000000  156.286628  720.0  1025.0  1085.0  1205.0  1500.0
#
#       Price-Weight                                                        \
#              count        mean         std    min     25%    50%     75%
# Breed
# AAX           17.0  441.941176  121.169030  215.0  375.00  390.0  525.00
# ...

# %% [markdown]
# #### Week3

# %%
week3 = df[df["Date"] == '10/11/2018']

# %%
week3
# Out:
#      Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 159   720.0        1.0  1140.0   AAX          1.58         420.0  10/11/2018
# 160   690.0        1.0  1120.0   AAX          1.62         430.0  10/11/2018
# 168   505.0        1.0   970.0   CHX          1.92         465.0  10/11/2018
# 169   530.0        1.0  1070.0   LMX          2.02         540.0  10/11/2018
# 170   495.0        1.0  1090.0   LMX          2.20         595.0  10/11/2018
# 171   365.0        1.0   730.0   CHX          2.00         365.0  10/11/2018
# 172   400.0        1.0   865.0   CHX          2.16         465.0  10/11/2018
# 173   585.0        1.0  1140.0   CHX          1.95         555.0  10/11/2018
# 177   465.0        1.0   800.0   LMX          1.72         335.0  10/11/2018
# 178   450.0        1.0  1000.0   LMX          2.22         550.0  10/11/2018
# 179   515.0        2.0  1050.0   LMX          2.04         535.0  10/11/2018
# ...

# %%
week2.groupby("Breed").describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        17.0  1.352941  0.606339  1.0  1.0  1.0  2.0  3.0  17.0
# CHX        46.0  1.260870  0.491473  1.0  1.0  1.0  1.0  3.0  46.0
# LMX        50.0  1.260000  0.564602  1.0  1.0  1.0  1.0  3.0  50.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX    1007.647059  173.260260  600.0   900.0  1010.0  1100.0  1360.0
# CHX    1167.934783  200.079362  910.0  1032.5  1120.0  1267.5  1860.0
# LMX    1093.000000  156.286628  720.0  1025.0  1085.0  1205.0  1500.0
#
#       Price-Weight                                                        \
#              count        mean         std    min     25%    50%     75%
# Breed
# AAX           17.0  441.941176  121.169030  215.0  375.00  390.0  525.00
# ...

# %%
AXY= week3[week3["Breed"] == "AAX"]
CXY = week3[week3["Breed"] == "CHX"]
LXY = week3[week3["Breed"] == "LMX"]

# %%
AXY.groupby("No.Owners").describe()
# Out:
#           Price                                                               \
#           count      mean         std    min     25%     50%     75%     max
# No.Owners
# 1.0        24.0   978.125  177.493493  560.0  850.00   955.0  1122.5  1240.0
# 2.0         6.0  1042.500  205.857961  700.0  983.75  1055.0  1145.0  1310.0
#
#           Price-Weight                                                        \
#                  count        mean         std    min     25%    50%     75%
# No.Owners
# 1.0               24.0  435.416667  128.848720  160.0  338.75  420.0  501.25
# 2.0                6.0  492.500000  130.817048  260.0  487.00  494.0  551.25
#
#                  Price/Weight                                                \
#              max        count      mean       std   min   25%   50%     75%
# No.Owners
# 1.0        665.0         24.0  1.801250  0.217921  1.40  1.62  1.77  1.9050
# 2.0        652.0          6.0  1.896667  0.208583  1.59  1.76  1.95  2.0275
#
# ...

# %%
LXY.groupby("No.Owners").describe()
# Out:
#           Price                                                          \
#           count         mean         std    min     25%     50%     75%
# No.Owners
# 1.0        36.0  1078.750000  202.334147  520.0  1000.0  1095.0  1232.5
# 2.0        11.0  1059.545455  210.195796  655.0   910.0  1110.0  1220.0
# 3.0         3.0   990.000000   51.961524  930.0   975.0  1020.0  1020.0
# 4.0         1.0   820.000000         NaN  820.0   820.0   820.0   820.0
#
#                   Price-Weight                                               \
#               max        count        mean         std    min    25%    50%
# No.Owners
# 1.0        1360.0         36.0  557.361111  150.444513  195.0  465.0  592.5
# 2.0        1300.0         11.0  552.363636  137.510925  323.0  450.5  570.0
# 3.0        1020.0          3.0  536.666667   63.105731  467.0  510.0  553.0
# 4.0         820.0          1.0  468.000000         NaN  468.0  468.0  468.0
#
# ...

# %%
CXY.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1.0        42.0  1159.880952  165.965351   730.0  1052.5  1190.0  1290.0
# 2.0         9.0  1057.777778  119.245312   760.0  1060.0  1110.0  1120.0
# 3.0         3.0  1236.666667   20.816660  1220.0  1225.0  1230.0  1245.0
#
#                   Price-Weight                                               \
#               max        count        mean         std    min    25%    50%
# No.Owners
# 1.0        1500.0         42.0  617.023810  110.039126  365.0  555.0  635.0
# 2.0        1140.0          9.0  592.777778   83.749295  400.0  605.0  610.0
# 3.0        1260.0          3.0  699.000000   20.074860  680.0  688.5  697.0
#
#                         Price/Weight                                         \
#              75%    max        count      mean       std   min   25%    50%
# No.Owners
# ...

# %%
AXY1 = AXY[AXY["No.Owners"] == 1] 
AXY1
AXY1['Weight']
# Out:
# 159    720.0
# 160    690.0
# 181    515.0
# 184    560.0
# 186    530.0
# 190    500.0
# 191    500.0
# 202    490.0
# 234    640.0
# 235    580.0
# 239    535.0
# 240    560.0
# 249    555.0
# 276    510.0
# 277    470.0
# 291    495.0
# 295    505.0
# 297    565.0
# 314    655.0
# 323    575.0
# 324    565.0
# 327    400.0
# 328    520.0
# 329    390.0
# Name: Weight, dtype: float64

# %%
AXY2 = AXY[AXY["No.Owners"] == 2] 
AXY2
AXY2['Weight']
# Out:
# 180    472.0
# 185    545.0
# 198    500.0
# 222    440.0
# 321    685.0
# 322    658.0
# Name: Weight, dtype: float64

# %%
LXY1 = LXY[LXY["No.Owners"] == 1] 
LXY1
LXY1['Weight']
# Out:
# 169    530.0
# 170    495.0
# 177    465.0
# 178    450.0
# 188    480.0
# 192    455.0
# 199    365.0
# 200    485.0
# 204    500.0
# 213    570.0
# 217    530.0
# 224    545.0
# 228    310.0
# 231    540.0
# 237    550.0
# 238    655.0
# 245    520.0
# 248    490.0
# 252    560.0
# 253    550.0
# 255    590.0
# 263    605.0
# 268    575.0
# 269    460.0
# 271    480.0
# 274    480.0
# 292    680.0
# 302    545.0
# 304    600.0
# 308    555.0
# 309    535.0
# 315    560.0
# 316    575.0
# 318    475.0
# 319    685.0
# 326    325.0
# Name: Weight, dtype: float64

# %%
LXY2 = LXY[LXY["No.Owners"] == 2] 
LXY2
LXY2['Weight']
# Out:
# 179    515.0
# 218    598.0
# 219    520.0
# 223    565.0
# 226    332.0
# 247    515.0
# 262    525.0
# 280    394.0
# 293    630.0
# 294    445.0
# 317    540.0
# Name: Weight, dtype: float64

# %%
LXY3 = LXY[LXY["No.Owners"] == 3] 
LXY3
LXY3['Weight']
# Out:
# 207    467.0
# 225    463.0
# 272    430.0
# Name: Weight, dtype: float64

# %%
CXY1 = CXY[CXY["No.Owners"] == 1] 
CXY1
CXY1['Weight']
# Out:
# 168    505.0
# 171    365.0
# 172    400.0
# 173    585.0
# 201    540.0
# 203    475.0
# 210    500.0
# 211    575.0
# 212    550.0
# 214    560.0
# 215    675.0
# 216    570.0
# 220    430.0
# 230    510.0
# 233    540.0
# 236    545.0
# 251    530.0
# 254    600.0
# 256    630.0
# 257    560.0
# 260    615.0
# 261    495.0
# 265    470.0
# 266    595.0
# 267    515.0
# 270    445.0
# 273    455.0
# 275    530.0
# 282    635.0
# 283    605.0
# 284    640.0
# 285    660.0
# 286    600.0
# 287    525.0
# 288    510.0
# 289    540.0
# 300    620.0
# 301    615.0
# 303    565.0
# 305    605.0
# 311    470.0
# 312    445.0
# Name: Weight, dtype: float64

# %%
CXY2 = CXY[CXY["No.Owners"] == 2] 
CXY2
CXY2['Weight']
# Out:
# 189    478.0
# 197    452.0
# 208    472.0
# 209    440.0
# 227    360.0
# 241    508.0
# 243    500.0
# 244    460.0
# 250    515.0
# Name: Weight, dtype: float64

# %%
CXY3 = CXY[CXY["No.Owners"] == 3] 
CXY3
CXY3['Weight']
# Out:
# 242    500.0
# 258    580.0
# 259    533.0
# Name: Weight, dtype: float64

# %%
e1=np.corrcoef(AXY1['Weight'], AXY1['Price'])[0, 1]
e2 = np.corrcoef(AXY2['Weight'], AXY2['Price'])[0, 1]
##d3 = np.corrcoef(AXW3['Weight'], AXW3['Price'])[0, 1]
e4 = np.corrcoef(LXY1['Weight'], LXY1['Price'])[0, 1]
e5 = np.corrcoef(LXY2['Weight'], LXY2['Price'])[0, 1]
e6 = np.corrcoef(LXY3['Weight'], LXY3['Price'])[0, 1]
e7 = np.corrcoef(CXY1['Weight'], CXY1['Price'])[0, 1]
e8= np.corrcoef(CXY2['Weight'], CXY2['Price'])[0, 1]
e9 = np.corrcoef(CXY3['Weight'], CXY3['Price'])[0, 1]

# %%
breed3 = ["AAX","CHX", "LMX"]
breed3 = np.random.choice(breed3, 134, p=[30/134,50/134 , 54/134])

# %%
breed3
# Out:
# array(['LMX', 'LMX', 'AAX', 'LMX', 'LMX', 'AAX', 'LMX', 'LMX', 'CHX',
#        'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'LMX', 'CHX',
#        'LMX', 'LMX', 'CHX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'CHX',
#        'AAX', 'LMX', 'LMX', 'AAX', 'AAX', 'CHX', 'LMX', 'LMX', 'LMX',
#        'CHX', 'AAX', 'AAX', 'LMX', 'AAX', 'CHX', 'CHX', 'CHX', 'LMX',
#        'AAX', 'AAX', 'AAX', 'CHX', 'AAX', 'AAX', 'LMX', 'CHX', 'CHX',
#        'LMX', 'CHX', 'CHX', 'CHX', 'AAX', 'CHX', 'AAX', 'CHX', 'CHX',
#        'CHX', 'CHX', 'CHX', 'LMX', 'LMX', 'LMX', 'LMX', 'CHX', 'AAX',
#        'LMX', 'LMX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'AAX', 'AAX',
#        'LMX', 'CHX', 'CHX', 'LMX', 'LMX', 'CHX', 'LMX', 'LMX', 'LMX',
#        'LMX', 'CHX', 'CHX', 'AAX', 'LMX', 'AAX', 'LMX', 'LMX', 'AAX',
#        'LMX', 'LMX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX',
#        'AAX', 'LMX', 'CHX', 'LMX', 'AAX', 'CHX', 'LMX', 'LMX', 'CHX',
# ...

# %%
ndf3 = pd.DataFrame(breed3, columns = ['Breed'])

No_Owners3 = []


# For each row in the column,
for row in ndf3['Breed']:
    # if more than a value,
    if row == "AAX":
        a = np.random.choice(no, p=[24/30, 6/30])
        No_Owners3.append(a)
    # else, if more than a value,
    elif row == "LMX":
        b = np.random.choice(no2,p=[36/50, 11/50, 3/50])
        # Append a letter grade
        No_Owners3.append(b)
    # else, if more than a value,
    elif row == "CHX":
        c = np.random.choice(no2,p=[42/54, 9/54, 3/54])
        # Append a letter grade
        No_Owners3.append(c)

# Create a column from the list
ndf3['No.Owners'] = No_Owners3

ndf3
# Out:
#     Breed  No.Owners
# 0     LMX          1
# 1     LMX          1
# 2     AAX          1
# 3     LMX          1
# 4     LMX          1
# 5     AAX          1
# 6     LMX          1
# 7     LMX          1
# 8     CHX          2
# 9     LMX          2
# 10    CHX          1
# 11    LMX          1
# 12    CHX          1
# 13    LMX          2
# 14    CHX          3
# 15    LMX          1
# 16    LMX          1
# 17    CHX          1
# 18    LMX          1
# 19    LMX          1
# 20    CHX          2
# 21    CHX          1
# 22    LMX          2
# 23    CHX          1
# 24    LMX          1
# 25    CHX          2
# 26    CHX          2
# 27    AAX          1
# 28    LMX          1
# 29    LMX          1
# 30    AAX          1
# 31    AAX          1
# 32    CHX          1
# 33    LMX          1
# 34    LMX          1
# 35    LMX          2
# 36    CHX          1
# 37    AAX          1
# 38    AAX          1
# 39    LMX          3
# 40    AAX          1
# 41    CHX          1
# ...

# %%
price3 = []

# For each row in the column,
for row in ndf3['Breed']:
    # if more than a value,
    if row == "AAX" and 1:
        xx = np.array([390.0, 720.0])
        yy = np.array([560.0, 1240.0])
        means = [542.708333,978.125]  
        stds = [78.310685, 177.493493 ]
        corr = e1 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        d = np.random.multivariate_normal(means, covs)
        price3.append(d)
    # else, if more than a value,
    elif row == "AAX" and 2:
        xx = np.array([440.0, 685.0])
        yy = np.array([700.0, 1310.0])
        means = [550.000000,1042.500]  
        stds = [100.596223, 205.857961]
        corr = e2 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        e = np.random.multivariate_normal(means, covs)
        price3.append(e)
    elif row == "LMX" and 1:
        xx = np.array([310.0, 685.0])
        yy = np.array([520.0, 1360.0])
        means = [521.388889,1078.750000]  
        stds = [82.502044, 202.334147]
        corr = e4 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price3.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 2:
        xx = np.array([332.0, 630.0])
        yy = np.array([655.0, 1300.0])
        means = [507.181818,1059.545455]  
        stds = [87.018180, 210.195796]
        corr = e5 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price3.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 3:
        xx = np.array([430.0, 467.0])
        yy = np.array([930.0, 1020.0])
        means = [453.333333,990.000000]  
        stds = [20.305993, 51.961524 ]
        corr = e6 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        g = np.random.multivariate_normal(means, covs)
        price3.append(g) 
    elif row == "CHX" and 1:
        xx = np.array([365.0, 675.0])
        yy = np.array([730.0, 1500.0])
        means = [542.857143,1159.880952]  
        stds = [71.696709, 165.965351]
        corr = e7 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        h = np.random.multivariate_normal(means, covs)
        price3.append(h)
    elif row == "CHX" and 2:
        xx = np.array([360.0, 515.0])
        yy = np.array([760.0, 1140.0])
        means = [465.000000,1057.777778]  
        stds = [46.952103, 119.245312 ]
        corr = e8 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        i = np.random.multivariate_normal(means, covs)
        price3.append(i)
    elif row == "CHX" and 2:
        xx = np.array([500.0, 580.0])
        yy = np.array([1220.0, 1260.0])
        means = [537.666667,1236.666667]  
        stds = [40.203648, 20.816660]
        corr = e9 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        i = np.random.multivariate_normal(means, covs)
        price3.append(i)    


# Create a column from the list

ndf3
# Out:
#     Breed  No.Owners
# 0     LMX          1
# 1     LMX          1
# 2     AAX          1
# 3     LMX          1
# 4     LMX          1
# 5     AAX          1
# 6     LMX          1
# 7     LMX          1
# 8     CHX          2
# 9     LMX          2
# 10    CHX          1
# 11    LMX          1
# 12    CHX          1
# 13    LMX          2
# 14    CHX          3
# 15    LMX          1
# 16    LMX          1
# 17    CHX          1
# 18    LMX          1
# 19    LMX          1
# 20    CHX          2
# 21    CHX          1
# 22    LMX          2
# 23    CHX          1
# 24    LMX          1
# 25    CHX          2
# 26    CHX          2
# 27    AAX          1
# 28    LMX          1
# 29    LMX          1
# 30    AAX          1
# 31    AAX          1
# 32    CHX          1
# 33    LMX          1
# 34    LMX          1
# 35    LMX          2
# 36    CHX          1
# 37    AAX          1
# 38    AAX          1
# 39    LMX          3
# 40    AAX          1
# 41    CHX          1
# ...

# %%
price3 =   np.concatenate([price3], axis=1)
price3
# Out:
# array([[ 592.23405269,  998.3983977 ],
#        [ 550.14370705, 1257.664835  ],
#        [ 596.00861594, 1138.12417491],
#        [ 552.70600854, 1004.33709191],
#        [ 532.19141714, 1161.99544837],
#        [ 637.10143299, 1088.55605498],
#        [ 524.52626006,  925.54190278],
#        [ 584.15549398, 1330.96407212],
#        [ 580.49803145, 1165.36913409],
#        [ 679.83636697, 1579.86901041],
#        [ 682.99658114, 1555.1327179 ],
#        [ 426.22504412,  717.39457621],
#        [ 549.96288697, 1086.29659394],
#        [ 618.18016259, 1408.62955536],
#        [ 512.82275711,  998.97301828],
#        [ 408.22208451,  998.25313926],
#        [ 582.56247686, 1208.97816911],
#        [ 444.82364513, 1002.27210669],
#        [ 522.83223526,  990.95227862],
#        [ 456.2833039 , 1060.8380709 ],
#        [ 514.60731034, 1045.97256097],
#        [ 611.2825033 , 1457.54945894],
#        [ 702.981651  , 1497.1948737 ],
#        [ 572.27880795, 1185.49498823],
# ...

# %%
nprice3 = price3[:,1]

# %%
weight3 = price3[:,0]

# %%
ndf3['Weight'] = weight3
ndf3['Price']  = nprice3
ndf3
# Out:
#     Breed  No.Owners      Weight        Price
# 0     LMX          1  592.234053   998.398398
# 1     LMX          1  550.143707  1257.664835
# 2     AAX          1  596.008616  1138.124175
# 3     LMX          1  552.706009  1004.337092
# 4     LMX          1  532.191417  1161.995448
# 5     AAX          1  637.101433  1088.556055
# 6     LMX          1  524.526260   925.541903
# 7     LMX          1  584.155494  1330.964072
# 8     CHX          2  580.498031  1165.369134
# 9     LMX          2  679.836367  1579.869010
# 10    CHX          1  682.996581  1555.132718
# 11    LMX          1  426.225044   717.394576
# 12    CHX          1  549.962887  1086.296594
# 13    LMX          2  618.180163  1408.629555
# 14    CHX          3  512.822757   998.973018
# 15    LMX          1  408.222085   998.253139
# 16    LMX          1  582.562477  1208.978169
# 17    CHX          1  444.823645  1002.272107
# 18    LMX          1  522.832235   990.952279
# ...

# %%
ndf3['Price/Weight'] = ndf3['Price']/ndf3['Weight']
ndf3
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight
# 0     LMX          1  592.234053   998.398398      1.685817
# 1     LMX          1  550.143707  1257.664835      2.286066
# 2     AAX          1  596.008616  1138.124175      1.909577
# 3     LMX          1  552.706009  1004.337092      1.817127
# 4     LMX          1  532.191417  1161.995448      2.183416
# 5     AAX          1  637.101433  1088.556055      1.708607
# 6     LMX          1  524.526260   925.541903      1.764529
# 7     LMX          1  584.155494  1330.964072      2.278441
# 8     CHX          2  580.498031  1165.369134      2.007533
# 9     LMX          2  679.836367  1579.869010      2.323896
# 10    CHX          1  682.996581  1555.132718      2.276926
# 11    LMX          1  426.225044   717.394576      1.683136
# 12    CHX          1  549.962887  1086.296594      1.975218
# 13    LMX          2  618.180163  1408.629555      2.278672
# 14    CHX          3  512.822757   998.973018      1.947989
# ...

# %%
ndf3['Price-Weight'] = ndf3['Price']- ndf3['Weight']

# %%
ndf3['Date'] = '10/11/2018'
ndf3
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight  Price-Weight  \
# 0     LMX          1  592.234053   998.398398      1.685817    406.164345
# 1     LMX          1  550.143707  1257.664835      2.286066    707.521128
# 2     AAX          1  596.008616  1138.124175      1.909577    542.115559
# 3     LMX          1  552.706009  1004.337092      1.817127    451.631083
# 4     LMX          1  532.191417  1161.995448      2.183416    629.804031
# 5     AAX          1  637.101433  1088.556055      1.708607    451.454622
# 6     LMX          1  524.526260   925.541903      1.764529    401.015643
# 7     LMX          1  584.155494  1330.964072      2.278441    746.808578
# 8     CHX          2  580.498031  1165.369134      2.007533    584.871103
# 9     LMX          2  679.836367  1579.869010      2.323896    900.032643
# 10    CHX          1  682.996581  1555.132718      2.276926    872.136137
# 11    LMX          1  426.225044   717.394576      1.683136    291.169532
# ...

# %%
ndf3.groupby('Breed').describe()
# Out:
#       No.Owners                                               Price  \
#           count      mean       std  min  25%  50%   75%  max count
# Breed
# AAX        30.0  1.166667  0.379049  1.0  1.0  1.0  1.00  2.0  30.0
# CHX        46.0  1.369565  0.609506  1.0  1.0  1.0  2.00  3.0  46.0
# LMX        58.0  1.293103  0.530098  1.0  1.0  1.0  1.75  3.0  58.0
#
#                                                                       \
#               mean         std         min          25%          50%
# Breed
# AAX    1010.976876  136.021034  609.696325   961.768053  1006.489296
# CHX    1153.667748  178.360412  773.908884  1027.875313  1103.259642
# LMX    1094.496805  224.880969  592.358574   935.883050  1053.248570
#
#                                 Price-Weight                          \
#                75%          max        count        mean         std
# Breed
# AAX    1096.983863  1291.423750         30.0  457.567072  104.037741
# ...

# %%
week3.groupby('Breed').describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        30.0  1.200000  0.406838  1.0  1.0  1.0  1.0  2.0  30.0
# CHX        54.0  1.277778  0.563569  1.0  1.0  1.0  1.0  3.0  54.0
# LMX        51.0  1.392157  0.695081  1.0  1.0  1.0  2.0  4.0  51.0
#
#                                                                         \
#               mean         std    min      25%     50%     75%     max
# Breed
# AAX     991.000000  181.599218  560.0   876.25  1005.0  1127.5  1310.0
# CHX    1147.129630  159.402191  730.0  1060.00  1140.0  1257.5  1500.0
# LMX    1064.313725  198.196921  520.0   960.00  1080.0  1225.0  1360.0
#
#       Price-Weight                                                        \
#              count        mean         std    min     25%    50%     75%
# Breed
# AAX           30.0  446.833333  129.061889  160.0  350.00  455.0  525.00
# ...

# %%
        ##xx = np.array([500.0, 580.0])
        ##yy = np.array([1220.0, 1260.0])
        means = [537.666667,1236.666667]  
        stds = [40.203648, 20.816660]
        corr = e9 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        i = np.random.multivariate_normal(means, covs)
        i
# Out:
# array([ 499.32407144, 1222.02230386])

# %% [markdown]
# #### Week 4

# %%
week4 = df[df["Date"] == '03/11/2018']

# %%
week4
# Out:
#      Weight  No.Owners   Price Breed  Price/Weight  Price-Weight        Date
# 0     590.0        1.0   980.0   AAX          1.66         390.0  03/11/2018
# 1     570.0        1.0  1000.0   AAX          1.75         430.0  03/11/2018
# 2     565.0        1.0   980.0   AAX          1.73         415.0  03/11/2018
# 3     620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 4     620.0        1.0  1000.0   AAX          1.61         380.0  03/11/2018
# 5     590.0        1.0   950.0   AAX          1.61         360.0  03/11/2018
# 6     560.0        1.0   970.0   AAX          1.73         410.0  03/11/2018
# 7     560.0        1.0   950.0   AAX          1.70         390.0  03/11/2018
# 8     572.0        1.0   965.0   AAX          1.69         393.0  03/11/2018
# 9     600.0        2.0  1060.0   AAX          1.77         460.0  03/11/2018
# 10    573.0        1.0   965.0   AAX          1.68         392.0  03/11/2018
# ...

# %%
week4.groupby("Breed").describe()
# Out:
#       No.Owners                                              Price  \
#           count      mean       std  min  25%  50%  75%  max count
# Breed
# AAX        21.0  1.333333  0.577350  1.0  1.0  1.0  2.0  3.0  21.0
# CHX        38.0  1.078947  0.273276  1.0  1.0  1.0  1.0  2.0  38.0
# LMX        52.0  1.326923  0.584813  1.0  1.0  1.0  2.0  3.0  52.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX     935.952381  154.407084  540.0   880.0   970.0  1000.0  1190.0
# CHX    1240.526316  191.395266  690.0  1145.0  1260.0  1365.0  1800.0
# LMX    1221.442308  155.148052  900.0  1117.5  1220.0  1332.5  1640.0
#
#       Price-Weight                                                        \
#              count        mean         std    min     25%    50%     75%
# Breed
# AAX           21.0  397.523810  101.188250  128.0  360.00  392.0  442.00
# ...

# %%
AXZ= week4[week4["Breed"] == "AAX"]
CXZ = week4[week4["Breed"] == "CHX"]
LXZ = week4[week4["Breed"] == "LMX"]

# %%
AXZ.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1.0        15.0   931.666667  131.565663   640.0   915.0   965.0   990.0
# 2.0         5.0   926.000000  234.904236   540.0   870.0  1040.0  1060.0
# 3.0         1.0  1050.000000         NaN  1050.0  1050.0  1050.0  1050.0
#
#                   Price-Weight                                                 \
#               max        count   mean         std    min    25%    50%    75%
# No.Owners
# 1.0        1190.0         15.0  385.0   73.600272  275.0  347.5  390.0  401.5
# 2.0        1120.0          5.0  424.6  173.328590  128.0  442.0  460.0  525.0
# 3.0        1050.0          1.0  450.0         NaN  450.0  450.0  450.0  450.0
#
#                  Price/Weight                                               \
#              max        count      mean       std   min    25%   50%   75%
# No.Owners
# ...

# %%
LXZ.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1.0        38.0  1218.552632  153.283468   900.0  1112.5  1220.0  1355.0
# 2.0        11.0  1254.545455  152.273677  1090.0  1160.0  1230.0  1295.0
# 3.0         3.0  1136.666667  215.019379   900.0  1045.0  1190.0  1255.0
#
#                   Price-Weight                                               \
#               max        count        mean         std    min    25%    50%
# No.Owners
# 1.0        1450.0         38.0  673.315789   99.548740  465.0  595.0  687.5
# 2.0        1640.0         11.0  696.727273  100.929769  578.0  606.0  710.0
# 3.0        1320.0          3.0  599.666667  250.066658  313.0  513.0  713.0
#
#                          Price/Weight                                    \
#               75%    max        count      mean       std   min     25%
# No.Owners
# ...

# %%
CXZ.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1.0        35.0  1243.714286  198.525235   690.0  1150.0  1270.0  1375.0
# 2.0         3.0  1203.333333   73.711148  1120.0  1175.0  1230.0  1245.0
#
#                   Price-Weight                                               \
#               max        count        mean         std    min    25%    50%
# No.Owners
# 1.0        1800.0         35.0  695.000000  125.662948  230.0  652.5  710.0
# 2.0        1260.0          3.0  717.333333   76.559345  632.0  686.0  740.0
#
#                          Price/Weight                                        \
#              75%     max        count      mean       std  min    25%   50%
# No.Owners
# 1.0        762.5  1025.0         35.0  2.271429  0.171329  1.5  2.195  2.29
# 2.0        760.0   780.0          3.0  2.480000  0.167033  2.3  2.405  2.51
#
# ...

# %%
AXZ1 = AXZ[AXZ["No.Owners"] == 1] 
AXZ1
AXZ1['Weight']
# Out:
# 0      590.0
# 1      570.0
# 2      565.0
# 3      620.0
# 4      620.0
# 5      590.0
# 6      560.0
# 7      560.0
# 8      572.0
# 10     573.0
# 20     430.0
# 96     365.0
# 101    590.0
# 117    545.0
# 152    450.0
# Name: Weight, dtype: float64

# %%
AXZ2 = AXZ[AXZ["No.Owners"] == 2] 
AXZ2
AXZ2['Weight']
# Out:
# 9      600.0
# 21     412.0
# 36     472.0
# 115    595.0
# 157    428.0
# Name: Weight, dtype: float64

# %%
LXZ1 = LXZ[LXZ["No.Owners"] == 1] 
LXZ1
LXZ1['Weight']
# Out:
# 22     435.0
# 32     625.0
# 33     560.0
# 37     535.0
# 38     450.0
# 41     610.0
# 42     590.0
# 43     605.0
# 59     480.0
# 66     490.0
# 67     530.0
# 71     520.0
# 72     655.0
# 73     680.0
# 74     640.0
# 76     629.0
# 82     670.0
# 83     620.0
# 84     595.0
# 85     495.0
# 90     465.0
# 91     410.0
# 94     620.0
# 97     575.0
# 100    480.0
# 120    515.0
# 121    500.0
# 126    525.0
# 128    540.0
# 131    540.0
# 133    610.0
# 134    575.0
# 135    550.0
# 138    505.0
# 140    435.0
# 141    490.0
# 143    425.0
# 155    545.0
# Name: Weight, dtype: float64

# %%
LXZ2 = LXZ[LXZ["No.Owners"] == 2] 
LXZ2
LXZ2['Weight']
# Out:
# 12     590.0
# 48     540.0
# 61     505.0
# 62     522.0
# 80     540.0
# 81     538.0
# 104    460.0
# 112    628.0
# 118    730.0
# 124    543.0
# 156    540.0
# Name: Weight, dtype: float64

# %%
LXZ3 = LXZ[LXZ["No.Owners"] == 3] 
LXZ3
LXZ3['Weight']
# Out:
# 11     547.0
# 18     477.0
# 111    587.0
# Name: Weight, dtype: float64

# %%
CXZ1 = CXZ[CXZ["No.Owners"] == 1] 
CXZ1
CXZ1['Weight']
# Out:
# 23     560.0
# 24     595.0
# 27     610.0
# 28     600.0
# 29     620.0
# 30     575.0
# 31     650.0
# 44     580.0
# 45     515.0
# 46     480.0
# 50     460.0
# 54     465.0
# 55     425.0
# 56     485.0
# 65     655.0
# 68     525.0
# 69     545.0
# 75     665.0
# 77     670.0
# 86     585.0
# 87     550.0
# 92     510.0
# 98     595.0
# 102    525.0
# 105    460.0
# 106    520.0
# 119    775.0
# 123    515.0
# 127    490.0
# 129    615.0
# 136    560.0
# 142    385.0
# 150    505.0
# 151    350.0
# 154    585.0
# Name: Weight, dtype: float64

# %%
CXZ2 = CXZ[CXZ["No.Owners"] == 2] 
CXZ2
CXZ2['Weight']
# Out:
# 17     490.0
# 49     488.0
# 107    480.0
# Name: Weight, dtype: float64

# %%
f1=np.corrcoef(AXZ1['Weight'], AXZ1['Price'])[0, 1]
f2 = np.corrcoef(AXZ2['Weight'], AXZ2['Price'])[0, 1]
##d3 = np.corrcoef(AXW3['Weight'], AXW3['Price'])[0, 1]
f4 = np.corrcoef(LXZ1['Weight'], LXZ1['Price'])[0, 1]
f5 = np.corrcoef(LXZ2['Weight'], LXZ2['Price'])[0, 1]
f6 = np.corrcoef(LXZ3['Weight'], LXZ3['Price'])[0, 1]
f7 = np.corrcoef(CXZ1['Weight'], CXZ1['Price'])[0, 1]
f8= np.corrcoef(CXZ2['Weight'], CXZ2['Price'])[0, 1]
#f9 = np.corrcoef(CXZ3['Weight'], CXZ3['Price'])[0, 1]

# %%
breed4 = ["AAX","CHX", "LMX"]
breed4 = np.random.choice(breed4, 110, p=[20/110,52/110 , 38/110])

# %%
breed4
# Out:
# array(['LMX', 'LMX', 'CHX', 'LMX', 'CHX', 'LMX', 'AAX', 'LMX', 'LMX',
#        'CHX', 'CHX', 'CHX', 'CHX', 'AAX', 'CHX', 'LMX', 'LMX', 'CHX',
#        'CHX', 'CHX', 'CHX', 'CHX', 'LMX', 'CHX', 'LMX', 'AAX', 'AAX',
#        'CHX', 'CHX', 'LMX', 'AAX', 'AAX', 'AAX', 'AAX', 'LMX', 'CHX',
#        'CHX', 'CHX', 'CHX', 'AAX', 'CHX', 'AAX', 'LMX', 'AAX', 'CHX',
#        'CHX', 'LMX', 'CHX', 'CHX', 'CHX', 'CHX', 'CHX', 'AAX', 'LMX',
#        'CHX', 'CHX', 'LMX', 'CHX', 'CHX', 'LMX', 'CHX', 'AAX', 'LMX',
#        'LMX', 'LMX', 'CHX', 'CHX', 'LMX', 'CHX', 'LMX', 'CHX', 'AAX',
#        'LMX', 'AAX', 'CHX', 'LMX', 'AAX', 'LMX', 'LMX', 'LMX', 'LMX',
#        'LMX', 'AAX', 'CHX', 'CHX', 'CHX', 'CHX', 'LMX', 'LMX', 'AAX',
#        'LMX', 'LMX', 'CHX', 'CHX', 'CHX', 'LMX', 'CHX', 'AAX', 'CHX',
#        'LMX', 'LMX', 'CHX', 'CHX', 'LMX', 'LMX', 'CHX', 'CHX', 'CHX',
#        'LMX', 'LMX'], dtype='<U3')

# %%
ndf4 = pd.DataFrame(breed4, columns = ['Breed'])

No_Owners4 = []


# For each row in the column,
for row in ndf4['Breed']:
    # if more than a value,
    if row == "AAX":
        a = np.random.choice(no, p=[15/20, 5/20])
        No_Owners4.append(a)
    # else, if more than a value,
    elif row == "LMX":
        b = np.random.choice(no2,p=[38/52, 11/52, 3/52])
        # Append a letter grade
        No_Owners4.append(b)
    # else, if more than a value,
    elif row == "CHX":
        c = np.random.choice(no,p=[35/38, 3/38])
        # Append a letter grade
        No_Owners4.append(c)

# Create a column from the list
ndf4['No.Owners'] = No_Owners4

ndf4
# Out:
#     Breed  No.Owners
# 0     LMX          1
# 1     LMX          1
# 2     CHX          1
# 3     LMX          2
# 4     CHX          1
# 5     LMX          2
# 6     AAX          2
# 7     LMX          1
# 8     LMX          1
# 9     CHX          1
# 10    CHX          1
# 11    CHX          1
# 12    CHX          1
# 13    AAX          1
# 14    CHX          1
# 15    LMX          2
# 16    LMX          1
# 17    CHX          1
# 18    CHX          1
# 19    CHX          1
# 20    CHX          1
# 21    CHX          1
# 22    LMX          1
# 23    CHX          1
# 24    LMX          1
# 25    AAX          2
# 26    AAX          2
# 27    CHX          1
# 28    CHX          1
# 29    LMX          1
# 30    AAX          1
# 31    AAX          2
# 32    AAX          2
# 33    AAX          2
# 34    LMX          1
# 35    CHX          1
# 36    CHX          2
# 37    CHX          1
# 38    CHX          1
# 39    AAX          2
# 40    CHX          1
# 41    AAX          2
# ...

# %%
price4 = []

# For each row in the column,
for row in ndf4['Breed']:
    # if more than a value,
    if row == "AAX" and 1:
        xx = np.array([390.0, 720.0])
        yy = np.array([560.0, 1240.0])
        means = [546.666667,931.666667]  
        stds = [73.154110, 131.565663 ]
        corr = e1 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        d = np.random.multivariate_normal(means, covs)
        price4.append(d)
    # else, if more than a value,
    elif row == "AAX" and 2:
        xx = np.array([440.0, 685.0])
        yy = np.array([700.0, 1310.0])
        means = [501.400000,926.000000]  
        stds = [90.453303, 234.904236]
        corr = e2 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        e = np.random.multivariate_normal(means, covs)
        price4.append(e)
    elif row == "LMX" and 1:
        xx = np.array([310.0, 685.0])
        yy = np.array([520.0, 1360.0])
        means = [545.236842,1218.552632]  
        stds = [72.312921, 153.283468]
        corr = e4 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price4.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 2:
        xx = np.array([332.0, 630.0])
        yy = np.array([655.0, 1300.0])
        means = [557.818182,1254.545455]  
        stds = [71.283684, 152.273677]
        corr = e5 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        f = np.random.multivariate_normal(means, covs)
        price4.append(f) 
    # else, if more than a value,
    elif row == "LMX" and 3:
        xx = np.array([430.0, 467.0])
        yy = np.array([930.0, 1020.0])
        means = [537.000000,1136.666667]  
        stds = [55.677644, 215.019379 ]
        corr = e6 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        g = np.random.multivariate_normal(means, covs)
        price4.append(g) 
    elif row == "CHX" and 1:
        xx = np.array([365.0, 675.0])
        yy = np.array([730.0, 1500.0])
        means = [548.714286,1243.714286]  
        stds = [85.735082, 198.525235]
        corr = e7 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        h = np.random.multivariate_normal(means, covs)
        price4.append(h)
    elif row == "CHX" and 2:
        xx = np.array([360.0, 515.0])
        yy = np.array([760.0, 1140.0])
        means = [486.000000,1203.333333]  
        stds = [5.291503, 73.711148]
        corr = e8 # correlation
        covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 
        i = np.random.multivariate_normal(means, covs)
        price4.append(i)
 


# Create a column from the list

ndf4
# Out:
#     Breed  No.Owners
# 0     LMX          1
# 1     LMX          1
# 2     CHX          1
# 3     LMX          2
# 4     CHX          1
# 5     LMX          2
# 6     AAX          2
# 7     LMX          1
# 8     LMX          1
# 9     CHX          1
# 10    CHX          1
# 11    CHX          1
# 12    CHX          1
# 13    AAX          1
# 14    CHX          1
# 15    LMX          2
# 16    LMX          1
# 17    CHX          1
# 18    CHX          1
# 19    CHX          1
# 20    CHX          1
# 21    CHX          1
# 22    LMX          1
# 23    CHX          1
# 24    LMX          1
# 25    AAX          2
# 26    AAX          2
# 27    CHX          1
# 28    CHX          1
# 29    LMX          1
# 30    AAX          1
# 31    AAX          2
# 32    AAX          2
# 33    AAX          2
# 34    LMX          1
# 35    CHX          1
# 36    CHX          2
# 37    CHX          1
# 38    CHX          1
# 39    AAX          2
# 40    CHX          1
# 41    AAX          2
# ...

# %%
price4 =   np.concatenate([price4], axis=1)
price4
# Out:
# array([[ 653.40723277, 1568.47022663],
#        [ 514.0462157 , 1321.53802147],
#        [ 529.50740745, 1297.82704914],
#        [ 524.72033095, 1137.50058703],
#        [ 558.73951015, 1223.3985395 ],
#        [ 647.09996804, 1276.17476226],
#        [ 469.42424392,  883.67555194],
#        [ 489.48480373, 1074.45810515],
#        [ 576.77198295, 1210.802728  ],
#        [ 521.4524198 , 1130.06557392],
#        [ 576.83331944, 1267.3112862 ],
#        [ 563.11188003, 1354.65217609],
#        [ 607.53029926, 1434.91750408],
#        [ 617.10901449, 1022.42888815],
#        [ 425.83577189, 1225.09956223],
#        [ 552.20091004, 1270.65313066],
#        [ 478.77665307, 1190.59600077],
#        [ 439.20618268, 1044.08109713],
#        [ 614.73882475, 1326.97001526],
#        [ 574.86038266, 1521.96180925],
#        [ 512.20216374, 1067.71200833],
#        [ 638.91427399, 1393.47948686],
#        [ 649.80082754, 1379.91572897],
#        [ 547.17919002, 1189.30579537],
# ...

# %%
nprice4 = price4[:,1]

# %%
weight4 = price4[:,0]

# %%
ndf4['Weight'] = weight4
ndf4['Price']  = nprice4
ndf4
# Out:
#     Breed  No.Owners      Weight        Price
# 0     LMX          1  653.407233  1568.470227
# 1     LMX          1  514.046216  1321.538021
# 2     CHX          1  529.507407  1297.827049
# 3     LMX          2  524.720331  1137.500587
# 4     CHX          1  558.739510  1223.398539
# 5     LMX          2  647.099968  1276.174762
# 6     AAX          2  469.424244   883.675552
# 7     LMX          1  489.484804  1074.458105
# 8     LMX          1  576.771983  1210.802728
# 9     CHX          1  521.452420  1130.065574
# 10    CHX          1  576.833319  1267.311286
# 11    CHX          1  563.111880  1354.652176
# 12    CHX          1  607.530299  1434.917504
# 13    AAX          1  617.109014  1022.428888
# 14    CHX          1  425.835772  1225.099562
# 15    LMX          2  552.200910  1270.653131
# 16    LMX          1  478.776653  1190.596001
# 17    CHX          1  439.206183  1044.081097
# 18    CHX          1  614.738825  1326.970015
# ...

# %%
ndf4['Price/Weight'] = ndf4['Price']/ndf4['Weight']
ndf4
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight
# 0     LMX          1  653.407233  1568.470227      2.400448
# 1     LMX          1  514.046216  1321.538021      2.570854
# 2     CHX          1  529.507407  1297.827049      2.451008
# 3     LMX          2  524.720331  1137.500587      2.167823
# 4     CHX          1  558.739510  1223.398539      2.189569
# 5     LMX          2  647.099968  1276.174762      1.972145
# 6     AAX          2  469.424244   883.675552      1.882467
# 7     LMX          1  489.484804  1074.458105      2.195080
# 8     LMX          1  576.771983  1210.802728      2.099275
# 9     CHX          1  521.452420  1130.065574      2.167150
# 10    CHX          1  576.833319  1267.311286      2.197015
# 11    CHX          1  563.111880  1354.652176      2.405654
# 12    CHX          1  607.530299  1434.917504      2.361886
# 13    AAX          1  617.109014  1022.428888      1.656804
# 14    CHX          1  425.835772  1225.099562      2.876930
# ...

# %%
ndf4['Price-Weight'] = ndf4['Price']- ndf4['Weight']

# %%
ndf4['Date'] = '03/11/2018'
ndf4
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight  Price-Weight  \
# 0     LMX          1  653.407233  1568.470227      2.400448    915.062994
# 1     LMX          1  514.046216  1321.538021      2.570854    807.491806
# 2     CHX          1  529.507407  1297.827049      2.451008    768.319642
# 3     LMX          2  524.720331  1137.500587      2.167823    612.780256
# 4     CHX          1  558.739510  1223.398539      2.189569    664.659029
# 5     LMX          2  647.099968  1276.174762      1.972145    629.074794
# 6     AAX          2  469.424244   883.675552      1.882467    414.251308
# 7     LMX          1  489.484804  1074.458105      2.195080    584.973301
# 8     LMX          1  576.771983  1210.802728      2.099275    634.030745
# 9     CHX          1  521.452420  1130.065574      2.167150    608.613154
# 10    CHX          1  576.833319  1267.311286      2.197015    690.477967
# 11    CHX          1  563.111880  1354.652176      2.405654    791.540296
# ...

# %%
frames = [ndf, ndf2, ndf3,ndf4]

result = pd.concat(frames)

# %%
result
# Out:
#     Breed  No.Owners      Weight        Price  Price/Weight  Price-Weight  \
# 0     CHX          1  513.470850  1095.685321      2.133880    582.214471
# 1     LMX          1  645.918910  1275.672600      1.974973    629.753689
# 2     CHX          1  740.314255  1567.482856      2.117321    827.168600
# 3     CHX          1  499.674273  1112.364231      2.226179    612.689958
# 4     AAX          1  446.123571   778.086877      1.744106    331.963306
# 5     AAX          2  583.665145   942.798149      1.615307    359.133005
# 6     CHX          1  400.070041   873.004835      2.182130    472.934794
# 7     CHX          1  637.937974  1076.855919      1.688026    438.917945
# 8     CHX          1  649.870416  1518.366846      2.336415    868.496430
# 9     LMX          1  685.615858  1657.089223      2.416935    971.473365
# 10    LMX          1  637.709420  1344.945645      2.109026    707.236225
# 11    CHX          1  640.155757  1311.081813      2.048067    670.926056
# ...

# %%
plt.figure(figsize=(15,15))
ax = sns.lineplot(x="Date", y="Weight", hue="Breed",
               data=result)

# %%
plt.figure(figsize=(15,15))
ax = sns.lineplot(x="Date", y="Weight", hue="Breed",
               data=df)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data = result)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data = df)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price", data=result, hue ="Breed",style ="No.Owners",size ="Price/Weight")

# %%
# Out:
#   File "<ipython-input-353-205fbeead637>", line 1
#     test = df[df["Date"] == ['24/11/2018']
#                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price", data=df, hue ="Breed",style ="No.Owners",size ="Price/Weight")

# %%
df.groupby('Breed').describe()
# Out:
#       No.Owners                                                Price  \
#           count      mean       std  min  25%  50%   75%  max  count
# Breed
# AAX        82.0  1.280488  0.503675  1.0  1.0  1.0  1.75  3.0   82.0
# CHX       187.0  1.213904  0.483290  1.0  1.0  1.0  1.00  3.0  187.0
# LMX       179.0  1.301676  0.607581  1.0  1.0  1.0  1.00  4.0  179.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX     962.134146  176.365975  540.0   862.5   970.0  1080.0  1360.0
# CHX    1173.181818  187.818286  620.0  1060.0  1170.0  1290.0  1860.0
# LMX    1116.396648  199.924155  520.0  1000.0  1110.0  1255.0  1640.0
#
#       Price-Weight                                                      \
#              count        mean         std    min    25%    50%    75%
# Breed
# AAX           82.0  419.280488  120.933639  128.0  347.5  410.0  490.0
# ...

# %%
result.groupby('Breed').describe()
# Out:
#       No.Owners                                               Price  \
#           count      mean       std  min  25%  50%  75%  max  count
# Breed
# AAX        73.0  1.260274  0.441821  1.0  1.0  1.0  2.0  2.0   73.0
# CHX       201.0  1.169154  0.413816  1.0  1.0  1.0  1.0  3.0  201.0
# LMX       172.0  1.284884  0.567341  1.0  1.0  1.0  1.0  3.0  172.0
#
#                                                                       \
#               mean         std         min          25%          50%
# Breed
# AAX     955.602888  189.614779  516.835368   804.034208   975.207916
# CHX    1200.236802  211.778119  637.242932  1073.467719  1189.305795
# LMX    1134.378682  216.529137  561.757532   996.427924  1137.883172
#
#                                 Price-Weight                          \
#                75%          max        count        mean         std
# Breed
# AAX    1088.556055  1426.994338         73.0  422.321435  138.573915
# ...

# %%
g = sns.jointplot(x='Weight', y='Price', data = df,kind="kde", height=7, space=0)

# %%
sns.violinplot(data=result)
