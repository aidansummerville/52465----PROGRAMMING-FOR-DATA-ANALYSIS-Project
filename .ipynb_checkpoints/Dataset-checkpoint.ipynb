# %% [markdown]
# test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats  
import seaborn as sns
import scipy.stats as stats


from matplotlib.pyplot import scatter

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("mart.csv", header=None)

# %%
df.columns = ["Lot", "Ring", "Weight", "No.Owners","Price", "Total", "Breed", "Sex","Price/Weight", "Price-Weight","Date"]

# %%
df.head()
# Out:
#   Lot Ring  Weight  No.Owners  Price  Total Breed Sex  Price/Weight  \
# 0   1   CA   410.0          2    700   1400   HEX   M          1.71
# 1  1A   CA   450.0          2    790   1580   HEX   M          1.76
# 2  1B   CA   420.0          2    750   1500   HEX   M          1.79
# 3  1C   CA   385.0          1    660    660   HEX   M          1.71
# 4  1D   CA   385.0          1    650    650   HEX   M          1.69
#
#    Price-Weight        Date
# 0         290.0  29/09/2018
# 1         340.0  29/09/2018
# 2         330.0  29/09/2018
# 3         275.0  29/09/2018
# 4         265.0  29/09/2018

# %%
df.shape
# Out:
# (1430, 11)

# %%
df.ndim
# Out:
# 2

# %%
df.head()
# Out:
#   Lot Ring  Weight  No.Owners  Price  Total Breed Sex  Price/Weight  \
# 0   1   CA   410.0          2    700   1400   HEX   M          1.71
# 1  1A   CA   450.0          2    790   1580   HEX   M          1.76
# 2  1B   CA   420.0          2    750   1500   HEX   M          1.79
# 3  1C   CA   385.0          1    660    660   HEX   M          1.71
# 4  1D   CA   385.0          1    650    650   HEX   M          1.69
#
#    Price-Weight        Date
# 0         290.0  29/09/2018
# 1         340.0  29/09/2018
# 2         330.0  29/09/2018
# 3         275.0  29/09/2018
# 4         265.0  29/09/2018

# %%
df.tail()
# Out:
#       Lot Ring  Weight  No.Owners  Price  Total Breed Sex  Price/Weight  \
# 1425  19E   CA   585.0          1   1180   1180   CHX   M          2.02
# 1426  19H   CA   620.0          1   1320   1320   CHX   M          2.13
# 1427  19J   CA   410.0          1   1080   1080   LMX   M          2.63
# 1428  19T   CA   470.0          1   1030   1030   CHX   M          2.19
# 1429   20   CA   430.0          1    850    850   LMX   M          1.98
#
#       Price-Weight        Date
# 1425         595.0  24/11/2018
# 1426         700.0  24/11/2018
# 1427         670.0  24/11/2018
# 1428         560.0  24/11/2018
# 1429         420.0  24/11/2018

# %%
df.dtypes
# Out:
# Lot              object
# Ring             object
# Weight          float64
# No.Owners         int64
# Price             int64
# Total             int64
# Breed            object
# Sex              object
# Price/Weight    float64
# Price-Weight    float64
# Date             object
# dtype: object

# %%
df.describe()
# Out:
#             Weight    No.Owners        Price        Total  Price/Weight  \
# count  1430.000000  1430.000000  1430.000000  1430.000000   1430.000000
# mean    516.147902     1.250350  1089.479021  1352.709091      2.111601
# std      83.383321     0.550065   216.043348   614.612465      0.275126
# min     250.000000     1.000000   350.000000    74.000000      1.080000
# 25%     460.000000     1.000000   950.000000  1000.000000      1.952500
# 50%     512.000000     1.000000  1100.000000  1180.000000      2.165000
# 75%     565.000000     1.000000  1250.000000  1390.000000      2.310000
# max     890.000000     6.000000  1860.000000  5100.000000      2.850000
#
#        Price-Weight
# count   1430.000000
# mean     573.331119
# std      160.986215
# min       25.000000
# 25%      470.000000
# 50%      600.000000
# 75%      695.000000
# max     1115.000000

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price", data=df, hue ="Breed",style ="No.Owners",size ="Price/Weight")

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price/Weight",hue ="Breed", data=df,style ="No.Owners",size ="Price/Weight")

# %%
df.groupby("Breed").describe()
# Out:
#       No.Owners                                                Price  \
#           count      mean       std  min  25%  50%   75%  max  count
# Breed
# AAX       202.0  1.212871  0.507881  1.0  1.0  1.0  1.00  5.0  202.0
# AUX         1.0  1.000000       NaN  1.0  1.0  1.0  1.00  1.0    1.0
# BA          1.0  1.000000       NaN  1.0  1.0  1.0  1.00  1.0    1.0
# BAX        10.0  1.200000  0.421637  1.0  1.0  1.0  1.00  2.0   10.0
# BBX        33.0  1.090909  0.291937  1.0  1.0  1.0  1.00  2.0   33.0
# CH         22.0  1.227273  0.428932  1.0  1.0  1.0  1.00  2.0   22.0
# CHX       531.0  1.239171  0.511426  1.0  1.0  1.0  1.00  4.0  531.0
# FR         24.0  1.250000  0.675664  1.0  1.0  1.0  1.00  4.0   24.0
# FRX         3.0  1.333333  0.577350  1.0  1.0  1.0  1.50  2.0    3.0
# GAX         1.0  1.000000       NaN  1.0  1.0  1.0  1.00  1.0    1.0
# HEX        71.0  1.704225  1.047369  1.0  1.0  1.0  2.00  6.0   71.0
# ...

# %%
df = df.loc[df.Breed.isin(['AAX', 'CHX', 'LMX'])]
df
# Out:
#        Lot Ring  Weight  No.Owners  Price  Total Breed Sex  Price/Weight  \
# 11      4C   CA   345.0          1    550    550   AAX   M          1.59
# 12      4D   CA   345.0          1    550    550   AAX   M          1.59
# 14      4H   CA   485.0          1    960    960   LMX   M          1.98
# 16      4T   CA   400.0          1    650    650   LMX   M          1.63
# 17       5   CA   640.0          1   1280   1280   AAX   M          2.00
# 18      5A   CA   585.0          1   1170   1170   AAX   M          2.00
# 19      5B   CA   480.0          1   1050   1050   LMX   M          2.19
# 20      5C   CA   500.0          1   1090   1090   AAX   M          2.18
# 21      5D   CA   535.0          1    960    960   AAX   M          1.79
# 23      5H   CA   620.0          1   1360   1360   LMX   M          2.19
# 24      5J   CA   645.0          1   1420   1420   CHX   M          2.20
# 25      5T   CA   685.0          1   1350   1350   AAX   M          1.97
# ...

# %%
df = df.drop(columns=['Lot', 'Ring','Total','Sex'])

# %%
AAXdf = df[df["Breed"] == "AAX"]
CHXdf = df[df["Breed"] == "CHX"]
LMXdf = df[df["Breed"] == "LMX"]

# %%
df.groupby("Breed").describe()
# Out:
#       No.Owners                                               Price  \
#           count      mean       std  min  25%  50%  75%  max  count
# Breed
# AAX       202.0  1.212871  0.507881  1.0  1.0  1.0  1.0  5.0  202.0
# CHX       531.0  1.239171  0.511426  1.0  1.0  1.0  1.0  4.0  531.0
# LMX       392.0  1.250000  0.524343  1.0  1.0  1.0  1.0  4.0  392.0
#
#                                                                        \
#               mean         std    min     25%     50%     75%     max
# Breed
# AAX     959.331683  180.068185  500.0   860.0   965.0  1090.0  1370.0
# CHX    1173.333333  174.324843  580.0  1070.0  1180.0  1280.0  1860.0
# LMX    1124.821429  197.656588  520.0  1000.0  1130.0  1270.0  1720.0
#
#       Price-Weight                                                      \
#              count        mean         std    min    25%    50%    75%
# Breed
# AAX          202.0  447.475248  124.596471  128.0  380.0  441.0  535.0
# ...

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x="Weight", y="Price", data=df, hue ="Breed",style ="No.Owners",size ="Price/Weight")

# %%
plt.figure(figsize=(15,15))
sns.lmplot(x="Weight", y="Price", hue="Breed", data=df)

# %%
plt.figure(figsize=(15,15))
sns.lmplot(x="Weight", y="Price/Weight", hue="Breed", data=df)

# %%
plt.figure(figsize=(15,15))
x = df["Weight"] 
ax =sns.distplot(x)

# %%
plt.figure(figsize=(15,15))
x = df["Price"] 
ax =sns.distplot(x,rug=True)

# %%
df.describe()
# Out:
#             Weight    No.Owners        Price  Price/Weight  Price-Weight
# count  1125.000000  1125.000000  1125.000000   1125.000000   1125.000000
# mean    519.094222     1.238222  1118.004444      2.157236    598.910222
# std      80.548912     0.515038   199.261861      0.244931    144.890826
# min     275.000000     1.000000   500.000000      1.310000    128.000000
# 25%     470.000000     1.000000  1000.000000      2.020000    510.000000
# 50%     515.000000     1.000000  1130.000000      2.190000    615.000000
# 75%     565.000000     1.000000  1260.000000      2.330000    710.000000
# max     890.000000     5.000000  1860.000000      2.850000   1115.000000

# %%
df
# Out:
#       Weight  No.Owners  Price Breed  Price/Weight  Price-Weight        Date
# 11     345.0          1    550   AAX          1.59         205.0  29/09/2018
# 12     345.0          1    550   AAX          1.59         205.0  29/09/2018
# 14     485.0          1    960   LMX          1.98         475.0  29/09/2018
# 16     400.0          1    650   LMX          1.63         250.0  29/09/2018
# 17     640.0          1   1280   AAX          2.00         640.0  29/09/2018
# 18     585.0          1   1170   AAX          2.00         585.0  29/09/2018
# 19     480.0          1   1050   LMX          2.19         570.0  29/09/2018
# 20     500.0          1   1090   AAX          2.18         590.0  29/09/2018
# 21     535.0          1    960   AAX          1.79         425.0  29/09/2018
# 23     620.0          1   1360   LMX          2.19         740.0  29/09/2018
# 24     645.0          1   1420   CHX          2.20         775.0  29/09/2018
# ...

# %%
plt.figure(figsize=(15,15))
x = CHXdf["Weight"] 
ax =sns.distplot(x,rug=True)

# %%
CHXdf.describe()
# Out:
#            Weight   No.Owners        Price  Price/Weight  Price-Weight
# count  531.000000  531.000000   531.000000    531.000000    531.000000
# mean   524.193032    1.239171  1173.333333      2.246064    649.140301
# std     79.912416    0.511426   174.324843      0.183844    113.946945
# min    275.000000    1.000000   580.000000      1.480000    210.000000
# 25%    470.000000    1.000000  1070.000000      2.140000    590.000000
# 50%    515.000000    1.000000  1180.000000      2.260000    660.000000
# 75%    575.000000    1.000000  1280.000000      2.370000    730.000000
# max    890.000000    4.000000  1860.000000      2.760000   1115.000000

# %%
mu, sigma =536.591837, 93.92371 # mean and standard deviation
>>> s = np.random.normal(mu, sigma, 49)

# %%
mu, sigma = 547.369565, 107.553885 # mean and standard deviation
>>> s2 = np.random.normal(mu, sigma, 46)

# %%
s
# Out:
# array([660.96539974, 669.27192359, 379.46840544, 638.18234898,
#        361.07659371, 715.90682565, 491.03453737, 627.25034229,
#        533.34819531, 369.46286736, 507.51024441, 450.47445052,
#        489.88802875, 456.87091146, 405.5186365 , 477.56893788,
#        476.54391242, 534.42090026, 408.56604005, 345.46797694,
#        596.1928285 , 434.61237016, 573.06849795, 568.73292431,
#        602.83174478, 490.23460117, 563.54705808, 611.94530187,
#        632.07178843, 565.19143788, 575.81560215, 515.46095163,
#        760.61571834, 524.47130028, 629.51085265, 487.58608548,
#        515.62948696, 543.9379685 , 489.10474327, 579.98263689,
#        480.75208732, 364.31416811, 570.37932293, 482.25890568,
#        357.77979911, 506.52973814, 689.43350885, 502.95377081,
#        534.46460575])

# %%
s2
# Out:
# array([639.29897363, 369.35414589, 497.78218702, 616.07997436,
#        613.09587134, 646.61018155, 520.22407204, 493.42774395,
#        601.44248049, 556.23808847, 629.95323696, 753.11826848,
#        475.13205232, 530.43054498, 691.88997924, 493.40685356,
#        538.36108447, 337.01671429, 552.40037309, 555.77047724,
#        505.75136495, 519.91637846, 652.01364493, 748.25626666,
#        644.0429276 , 520.03504477, 490.34204995, 457.85843454,
#        483.96610134, 482.13450724, 595.32870545, 710.81587694,
#        380.11803528, 403.61480349, 625.88464546, 304.72760634,
#        615.71701735, 631.84085528, 763.76967228, 562.98530308,
#        380.13773085, 427.92210296, 651.48195387, 632.71497952,
#        476.67928689, 555.17413639])

# %%
ax =sns.distplot(s,rug=True)

# %%
ax2 =sns.distplot(s2,rug=True)

# %%
Date = CHXdf[CHXdf["Date"] == '29/09/2018']

# %%
Date
# Out:
#      Weight  No.Owners  Price Breed  Price/Weight  Price-Weight        Date
# 24    645.0          1   1420   CHX          2.20         775.0  29/09/2018
# 26    560.0          1   1200   CHX          2.14         640.0  29/09/2018
# 29    425.0          2   1040   CHX          2.45         615.0  29/09/2018
# 30    460.0          1   1080   CHX          2.35         620.0  29/09/2018
# 31    480.0          1   1190   CHX          2.48         710.0  29/09/2018
# 33    475.0          1   1000   CHX          2.11         525.0  29/09/2018
# 34    450.0          1   1070   CHX          2.38         620.0  29/09/2018
# 36    480.0          1   1050   CHX          2.19         570.0  29/09/2018
# 42    525.0          1   1220   CHX          2.32         695.0  29/09/2018
# 43    530.0          2   1180   CHX          2.23         650.0  29/09/2018
# 45    520.0          1   1280   CHX          2.46         760.0  29/09/2018
# ...

# %% [markdown]
# ### week1

# %%
Date.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1          54.0  1176.944444  211.607541   760.0  1030.0  1185.0  1297.5
# 2           9.0  1203.333333   75.332596  1040.0  1180.0  1200.0  1250.0
# 3           1.0  1140.000000         NaN  1140.0  1140.0  1140.0  1140.0
#
#                   Price-Weight                                                \
#               max        count        mean         std    min     25%    50%
# No.Owners
# 1          1790.0         54.0  647.129630  130.844867  330.0  576.25  642.5
# 2          1300.0          9.0  680.555556   59.289778  585.0  650.00  695.0
# 3          1140.0          1.0  557.000000         NaN  557.0  557.00  557.0
#
#                          Price/Weight                                          \
#              75%     max        count      mean       std   min     25%   50%
# No.Owners
# ...

# %%
no = Date[Date["No.Owners"] == '1']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-60765d02dccd> in <module>()
# ----> 1 no = Date[Date["No.Owners"] == '1']
#
# NameError: name 'Date' is not defined

# %%
numpy.corrcoef("", price)[0, 1]

# %%
xx = np.array([370.0, 770.0])
yy = np.array([760.0, 1790.0])
means = [529.814815,1176.944444]  
stds = [97.312776/ 3, 211.607541 / 3]
corr = .9  # correlation
covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 

m = np.random.multivariate_normal(means, covs, 54).T
scatter(m[0], m[1])

# %%
week1=   CHXdf[CHXdf["Date"] == "29/09/2018"]
x1 = week1["Weight"] 
## 29/9/18 charlie

y1 = week1["Price"]

# %%
import scipy.stats
lower = 370.0
upper = 770.0
mu = 529.814815
sigma = 97.312776
N = 54

w1_c_1= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w1_c_1,rug=True)

# %%
import scipy.stats
lower = 1.73
upper = 2.58
mu = 2.229444
sigma = 0.183698
N = 54

wp1_c_1= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp1_c_1,rug=True)

# %%
import scipy.stats
lower = 425.0
upper = 615.0
mu = 522.777778
sigma = 61.599062
N = 9

w1_c_2= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w1_c_2,rug=True)

# %%
import scipy.stats
lower = 1.95
upper = 2.57
mu = 2.321111
sigma = 0.200714
N = 9

wp1_c_2= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp1_c_2,rug=True)

# %%
wp1_c_3 =1.960000

w1_c_3= 583.0

# %%
plt.figure(figsize=(15,15))
ax = sns.lineplot(x="Date", y="Price", hue="Breed",
               data=df)

# %%
newdf1 = pd.DataFrame(np.column_stack([w1_c_1, wp1_c_1, w1_c_1*wp1_c_1,(w1_c_1*wp1_c_1)-w1_c_1]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
newdf1['No.Owners']='1' 

newdf2 = pd.DataFrame(np.column_stack([w1_c_2, wp1_c_2, w1_c_2*wp1_c_2,(w1_c_2*wp1_c_2)-w1_c_2]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
newdf2['No.Owners']='2' 

newdf3 = pd.DataFrame(np.column_stack([w1_c_3, wp1_c_3, w1_c_3*wp1_c_3,(w1_c_3*wp1_c_3)-w1_c_3]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
newdf3['No.Owners']='3'

# %%
frames = [newdf1, newdf2, newdf3]
result = pd.concat(frames)
result['Date']='29/09/2018'

# %%
result
# Out:
#         Weight  Weight/Price        Price  Price-Weight No.Owners        Date
# 0   658.132919      2.275899  1497.843878    839.710959         1  29/09/2018
# 1   459.362510      2.252014  1034.490734    575.128223         1  29/09/2018
# 2   536.338321      2.347488  1259.047945    722.709624         1  29/09/2018
# 3   589.903628      2.478175  1461.884380    871.980752         1  29/09/2018
# 4   448.619945      2.095748   940.194557    491.574611         1  29/09/2018
# 5   522.402788      2.353040  1229.234806    706.832018         1  29/09/2018
# 6   523.230047      2.427540  1270.161925    746.931878         1  29/09/2018
# 7   547.660727      2.266672  1241.367058    693.706331         1  29/09/2018
# 8   580.288419      2.026564  1175.991384    595.702966         1  29/09/2018
# 9   568.200601      2.065580  1173.663975    605.463374         1  29/09/2018
# 10  482.958722      2.356269  1137.980781    655.022058         1  29/09/2018
# ...

# %%
sns.scatterplot(x="Weight", y="Price",data=week1)
sns.scatterplot(x="Weight", y="Price",data=result)

# %% [markdown]
# #### week2

# %%
Date2 = CHXdf[CHXdf["Date"] == '06/10/2018']

# %%
Date2
# Out:
#      Weight  No.Owners  Price Breed  Price/Weight  Price-Weight        Date
# 187   447.5          2   1100   CHX          2.46         652.5  06/10/2018
# 188   490.0          1   1170   CHX          2.39         680.0  06/10/2018
# 189   475.0          1   1130   CHX          2.38         655.0  06/10/2018
# 190   455.0          1   1060   CHX          2.33         605.0  06/10/2018
# 193   490.0          1   1100   CHX          2.24         610.0  06/10/2018
# 194   505.0          2   1150   CHX          2.28         645.0  06/10/2018
# 199   545.0          1   1160   CHX          2.13         615.0  06/10/2018
# 205   480.0          1   1190   CHX          2.48         710.0  06/10/2018
# 206   415.0          1    950   CHX          2.29         535.0  06/10/2018
# 207   375.0          1    850   CHX          2.27         475.0  06/10/2018
# 210   565.0          1   1070   CHX          1.89         505.0  06/10/2018
# ...

# %%
Date2.groupby("No.Owners").describe()
# Out:
#           Price                                                           \
#           count         mean         std     min     25%     50%     75%
# No.Owners
# 1          58.0  1164.827586  144.734983   820.0  1092.5  1150.0  1250.0
# 2          11.0  1189.090909  115.797629   960.0  1110.0  1200.0  1275.0
# 3           1.0  1380.000000         NaN  1380.0  1380.0  1380.0  1380.0
#
#                   Price-Weight                                               \
#               max        count        mean        std    min     25%    50%
# No.Owners
# 1          1520.0         58.0  653.275862  95.253824  430.0  605.00  657.5
# 2          1360.0         11.0  667.090909  77.838557  490.0  648.75  675.0
# 3          1380.0          1.0  743.000000        NaN  743.0  743.00  743.0
#
#                         Price/Weight                                           \
#              75%    max        count      mean       std   min     25%    50%
# No.Owners
# ...

# %%
import scipy.stats
lower = 375.0
upper = 735.0
mu = 511.551724
sigma = 70.045141
N = 58

w2_c_1= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w2_c_1,rug=True)

# %%
import scipy.stats
lower = 1.87
upper = 2.63
mu = 2.286379
sigma = 0.173283
N = 58

wp2_c_1= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp2_c_1,rug=True)

# %%
import scipy.stats
lower = 447.5
upper = 600.0
mu =  522.000000
sigma = 50.771547
N = 11

w2_c_2= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w2_c_2,rug=True)

# %%
import scipy.stats
lower = 2.04
upper = 2.46
mu = 2.281818
sigma = 0.132123
N = 11

wp2_c_2= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp2_c_2,rug=True)

# %%
w2_c_3=637.000000
wp2_c_3=2.170000

# %%
new2df1 = pd.DataFrame(np.column_stack([w2_c_1, wp2_c_1, w2_c_1*wp2_c_1,(w2_c_1*wp2_c_1)-w2_c_1]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new2df1['No.Owners']='1' 

new2df2 = pd.DataFrame(np.column_stack([w2_c_2, wp2_c_2, w2_c_2*wp2_c_2,(w2_c_2*wp2_c_2)-w2_c_2]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new2df2['No.Owners']='2' 

new2df3 = pd.DataFrame(np.column_stack([w2_c_3, wp2_c_3, w2_c_3*wp2_c_3,(w2_c_3*wp2_c_3)-w2_c_3]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new2df3['No.Owners']='3'

# %%
frames2 = [new2df1, new2df2, new2df3]
result2 = pd.concat(frames2)
result2['Date']='06/10/2018'

# %%
result2
# Out:
#         Weight  Weight/Price        Price  Price-Weight No.Owners        Date
# 0   559.761010      2.547019  1425.722058    865.961048         1  06/10/2018
# 1   482.722355      2.271535  1096.520757    613.798402         1  06/10/2018
# 2   509.043325      2.196712  1118.221566    609.178240         1  06/10/2018
# 3   459.965713      2.100864   966.325208    506.359496         1  06/10/2018
# 4   424.856657      2.147904   912.551325    487.694668         1  06/10/2018
# 5   430.398437      2.096558   902.355247    471.956810         1  06/10/2018
# 6   598.291505      2.184986  1307.258589    708.967084         1  06/10/2018
# 7   491.161766      2.365116  1161.654599    670.492833         1  06/10/2018
# 8   648.454642      2.421589  1570.290711    921.836069         1  06/10/2018
# 9   541.031749      2.374922  1284.908130    743.876380         1  06/10/2018
# 10  540.840896      2.286936  1236.868426    696.027530         1  06/10/2018
# ...

# %%
week2=   CHXdf[CHXdf["Date"] == "06/10/2018"]

# %%
sns.scatterplot(x="Weight", y="Price",data=week2)
sns.scatterplot(x="Weight", y="Price",data=result2)

# %% [markdown]
# ### week3

# %%
Date3 = CHXdf[CHXdf["Date"] == '13/10/2018']

# %%
Date3
# Out:
#      Weight  No.Owners  Price Breed  Price/Weight  Price-Weight        Date
# 327   425.0          1   1000   CHX          2.35         575.0  13/10/2018
# 344   525.0          1   1140   CHX          2.17         615.0  13/10/2018
# 345   500.0          2   1100   CHX          2.20         600.0  13/10/2018
# 348   468.0          2   1060   CHX          2.26         592.0  13/10/2018
# 357   470.0          1   1040   CHX          2.21         570.0  13/10/2018
# 358   545.0          1   1260   CHX          2.31         715.0  13/10/2018
# 359   600.0          1   1250   CHX          2.08         650.0  13/10/2018
# 360   580.0          1   1200   CHX          2.07         620.0  13/10/2018
# 361   505.0          1   1100   CHX          2.18         595.0  13/10/2018
# 363   490.0          1   1170   CHX          2.39         680.0  13/10/2018
# 370   411.0          4    955   CHX          2.32         544.0  13/10/2018
# ...

# %%
Date3.groupby("No.Owners").describe()
# Out:
#           Price                                                            \
#           count         mean         std    min      25%     50%      75%
# No.Owners
# 1          39.0  1148.333333  214.820406  650.0  1020.00  1140.0  1280.00
# 2          13.0  1154.615385   92.881231  950.0  1100.00  1160.0  1230.00
# 3           2.0  1165.000000  332.340187  930.0  1047.50  1165.0  1282.50
# 4           2.0   917.500000   53.033009  880.0   898.75   917.5   936.25
#
#                   Price-Weight                                                \
#               max        count        mean         std    min     25%    50%
# No.Owners
# 1          1750.0         39.0  633.205128  162.559654  210.0  567.50  625.0
# 2          1280.0         13.0  666.923077   74.772390  502.0  632.00  670.0
# 3          1400.0          2.0  658.500000  214.253355  507.0  582.75  658.5
# 4           955.0          2.0  523.000000   29.698485  502.0  512.50  523.0
#
# ...

# %%
import scipy.stats
lower = 400.0
upper = 645.0
mu = 515.128205
sigma = 65.969363
N = 39

w3_c_1= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w3_c_1,rug=True)

# %%
import scipy.stats
lower = 1.48
upper = 2.76
mu = 2.219744
sigma = 0.237481
N = 39

wp3_c_1= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp3_c_1,rug=True)

# %%
import scipy.stats
lower = 448.0
upper = 530.0
mu =  487.692308
sigma = 24.536995
N = 13

w3_c_2= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w2_c_2,rug=True)

# %%
import scipy.stats
lower = 2.12
upper = 2.57
mu = 2.365385
sigma = 0.121971
N = 13

wp3_c_2= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp2_c_2,rug=True)

# %%
import scipy.stats
lower = 423.0
upper = 590.0
mu =  506.500000
sigma = 118.086832
N = 2

w3_c_3= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w3_c_3,rug=True)

# %%
import scipy.stats
lower = 2.12
upper = 2.57
mu = 2.365385
sigma = 0.121971
N = 2

wp3_c_3= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp3_c_3,rug=True)

# %%
import scipy.stats
lower = 378.0
upper = 411.0
mu =  394.500000
sigma = 23.334524
N = 2

w3_c_4= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(w3_c_4,rug=True)

# %%
import scipy.stats
lower = 2.32
upper = 2.33
mu =2.325000
sigma = 0.007071
N = 2

wp3_c_4= scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)


ax =sns.distplot(wp3_c_4,rug=True)

# %%
new3df1 = pd.DataFrame(np.column_stack([w3_c_1, wp3_c_1, w3_c_1*wp3_c_1,(w3_c_1*wp3_c_1)-w3_c_1]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new3df1['No.Owners']='1' 

new3df2 = pd.DataFrame(np.column_stack([w3_c_2, wp3_c_2, w3_c_2*wp3_c_2,(w3_c_2*wp3_c_2)-w3_c_2]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new3df2['No.Owners']='2' 

new3df3 = pd.DataFrame(np.column_stack([w3_c_3, wp3_c_3, w3_c_3*wp3_c_3,(w3_c_3*wp3_c_3)-w3_c_3]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new3df3['No.Owners']='3'

new3df4 = pd.DataFrame(np.column_stack([w3_c_4, wp3_c_4, w3_c_4*wp3_c_4,(w3_c_4*wp3_c_4)-w3_c_4]), 
                               columns=['Weight', 'Weight/Price','Price','Price-Weight'])
new3df4['No.Owners']='4'

# %%
frames3 = [new3df1, new3df2, new3df3, new3df4]
result3 = pd.concat(frames3)
result3['Date']='13/10/2018'

# %%
result3
# Out:
#         Weight  Weight/Price        Price  Price-Weight No.Owners        Date
# 0   624.001283      2.212671  1380.709695    756.708413         1  13/10/2018
# 1   570.516723      2.002649  1142.544569    572.027846         1  13/10/2018
# 2   491.759074      1.852579   911.022308    419.263233         1  13/10/2018
# 3   453.297701      2.436506  1104.462562    651.164861         1  13/10/2018
# 4   513.581182      2.231452  1146.031948    632.450766         1  13/10/2018
# 5   525.509300      2.190944  1151.361623    625.852322         1  13/10/2018
# 6   596.671566      1.987171  1185.688658    589.017092         1  13/10/2018
# 7   621.587755      1.869921  1162.320093    540.732338         1  13/10/2018
# 8   519.627472      2.246539  1167.363461    647.735989         1  13/10/2018
# 9   461.153985      2.362247  1089.359782    628.205796         1  13/10/2018
# 10  519.637677      2.257558  1173.112325    653.474648         1  13/10/2018
# ...

# %%
week3=   CHXdf[CHXdf["Date"] == "13/10/2018"]

# %%
sns.scatterplot(x="Weight", y="Price",data=week3)
sns.scatterplot(x="Weight", y="Price",data=result3)
